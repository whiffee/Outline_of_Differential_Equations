# %%
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# <div style="background: #DDE2FF;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 20px 5px 0px 5px;
#             border: 10px solid #DDE2FF;
#             margin-left: 1px;
#             margin-right: 1px;"
#
#  <font color='blue'>$\textbf{ Chapter 27: Power Series Solutions of Linear Differential Equations w Variable Coefficients}$. Finding and expressing differential equation solutions in terms of power series.<br><br>
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Note: When transcribing text for entry into Wolfram Alpha the "fenceposts" !| ... |! are excluded from the text.
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>27.2 Find a recurrence formula for the power series solution around $\:x\,=\,0\,$ for
#
# $$y\,''\,-\,xy\,'\,+\,2y\,=\,0\,$$
#
# </font>
# </div>

# %%
import sympy as sp
x = sp.Symbol('x')
y = sp.Function('y')(x)
yp = sp.Derivative(y, x)
ydp= sp.Derivative(y, x, x)
equation = sp.Eq(3*x + yp + 2*y, 0)
display(equation)
# Out:
# Eq(3*x + 2*y(x) + Derivative(y(x), x), 0)

# %%
solution = sp.dsolve(equation, hint='1st_power_series')
display(solution)
# Out:
# Eq(y(x), x**2*(4*C1 - 3)/2 - x**3*(4*C1 - 3)/3 + x**4*(4*C1 - 3)/6 - x**5*(4*C1 - 3)/15 + C1 - 2*C1*x + O(x**6))

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>For a restricted set of equations, (above), sympy has an ability to go straight to a series solution.
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Possibly it subverts the purpose of the problem set, but it might be possible to take a found solution and turn that into something in series form, all in Wolfram Alpha.
#
# For the present example, the W|A solution is much uglier than the sympy version, so the sympy version will be used.
#
# </font>
# </div>

# %%
equation2 = sp.Eq(ydp -x*yp + 2*y, 0)
solution = sp.dsolve(equation2)
display(solution)
# Out:
# Eq(y(x), C2*(1 - x**2) + C1*x*(1 - x**2/6) + O(x**6))

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>(Above): Surprise! For this particular equation, sympy prefers to display it in series form, anticipating the intent of the problem. However, sympy does not give enough information to guess the recurrence relation. A new kid on the block, Symbolab, chips in with a more detailed solution:
#
# $$y= c_1\left(1\,-\,x^2\right)\,+\,c_2\left(x\,-\,
# \frac{x^3}{6}\,-\frac{x^5}{120}\,+\,...\,+\frac{x^{2n\,+\,1}(-1)\,(1)\,(2n\,-3)}{(2)(3)(4)(5)\,...\,2n(2n\,+\,1)}\,+\,...\right)$$
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>27.3 Find a recurrence formula for the power series solution around $\:x\,=\,0\,$ for
#
# $$y\,''\,-\,xy\,'\,+\,2y\,=\,0\,$$
#
# </font>
# </div>

# %%
from sympy import *

x = symbols('x')
n = Symbol('n', positive=True, integer=True)
r = limit((-x**(2*n-1))/factorial(2*n - 1), x, oo)
if (r==0):
    print('nope')
else:
    print('converges to  ' + str(r))
print('limit of the given function  ' + str(r))
# Out:
# converges to  -oo
# limit of the given function  -oo

# %%
from sympy import *

x = symbols('x')
n = Symbol('n', positive=True, integer=True)
r = limit((-x**(2*n+1)*(2*n - 3))/factorial(2*n + 1), x, oo)
if (r==0):
    print('nope')
else:
    print('converges to  ' + str(r))
print('limit of the given function  ' + str(r))
# Out:
# converges to  -oo*sign(2*n - 3)
# limit of the given function  -oo*sign(2*n - 3)

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The above two cells show that neither rendition of the Symbolab solution converges.
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>27.5 Find a recurrence formula for the power series $\:y\,''\,+\,y\,'\,=\,0\,$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>If this differential equation is entered in Symbolab, the solution which is returned is:
#
# $$y \,=\,c_1\,\textrm{cos}\,(t)\,+\,c_2\,\textrm{sin}\,(t)$$
#
# The Maclaurin series for these two trig functions are equal to:
#
# $$\textrm{cos}\,(x)\,=\,1\,-\,\frac{x^2}{2!}\,+\,\frac{x^4}{4!}\,-\,\cdot\cdot\cdot\,=\,\sum_{n=0}^\infty\frac{(-1)^n\,x^{2n}}{(2n)!}$$
#
# $$\textrm{sin}\,(x)\,=\,1\,-\,\frac{x^3}{3!}\,+\,\frac{x^5}{5!}\,-\,\cdot\cdot\cdot\,=\,\sum_{n=0}^\infty\frac{(-1)^n\,x^{2n\,+\,1}}{(2n\,+\,1)!}$$
#
# No method for derivation of the recurrence formula based on the above information can be discerned. The derivation process, as developed by the text, is fairly involved.
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>27.9 Find a recurrence formula for the differential equation $\:y\,''\,+\,(t\,-\,1)\,y\,'\,+\,(2t\,-\,3)\,y\,=\,0\,$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Symbolab will not solve the problem equation. Maxima will not solve it either. Wolfram Alpha will solve it in a long, complicated solution containing the dreaded $\,\mathsf{erfi}\,$ function. The much more reasonable-looking solution of sympy can be seen below.
#
#
# </font>
# </div>

# %%
import sympy as sp

t = sp.Symbol('t')
y = sp.Function('y')(t)
yp = sp.Derivative(y, t)
ydp= sp.Derivative(y, t, t)
equation = sp.Eq(ydp + (t - 1)*yp + (2*t - 3)*y, 0)
display(equation)
# Out:
#                                       2
#         d                            d
# (t - 1)⋅──(y(t)) + (2⋅t - 3)⋅y(t) + ───(y(t)) = 0
#         dt                            2
#                                     dt

# %%
solution = sp.dsolve(equation)
display(solution)
# Out:
#           ⎛ 4    3      2    ⎞        ⎛ 2        ⎞
#           ⎜t    t    3⋅t     ⎟        ⎜t    t    ⎟    ⎛ 6⎞
# y(t) = C₂⋅⎜── + ── + ──── + 1⎟ + C₁⋅t⋅⎜── + ─ + 1⎟ + O⎝t ⎠
#           ⎝6    6     2      ⎠        ⎝2    2    ⎠

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Above: sympy chooses to couch its solution in terms of a series. Since that is the subject of this chapter, the choice is congenial. The answer does not comprise a recurrence formula, .
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>27.12 Find a recurrence formula for the differential equation $\:(1\,-\,x^2)\,y\,''\,-\,2xy\,'\,+\,n(n\,+\,1)\,y\,=\,0\,$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Considering the order and general structure of the problem equation, it seems unlikely that any except sympy will solve it.
#
# </font>
# </div>

# %%
import sympy as sp

n = symbols('n')
x = sp.Symbol('x')
y = sp.Function('y')(x)
yp = sp.Derivative(y, x)
ydp= sp.Derivative(y, x, x)
equation = sp.Eq((1 - x**2)*ydp - 2*x*yp + n*(n + 1)*y, 0)
display(equation)
# Out:
#                                            2
#                      d          ⎛     2⎞  d
# n⋅(n + 1)⋅y(x) - 2⋅x⋅──(y(x)) + ⎝1 - x ⎠⋅───(y(x)) = 0
#                      dx                    2
#                                          dx

# %%
solution = sp.dsolve(equation)
display(solution)
# Out:
#           ⎛ 4  4    3  4      2  4    2  2      4      2    ⎞        ⎛   2  2
#           ⎜n ⋅x    n ⋅x    5⋅n ⋅x    n ⋅x    n⋅x    n⋅x     ⎟        ⎜  n ⋅x
# y(x) = C₂⋅⎜───── + ───── - ─────── - ───── - ──── - ──── + 1⎟ + C₁⋅x⋅⎜- ─────
#           ⎝  24      12       24       2      4      2      ⎠        ⎝    6
#
#      2    2    ⎞
#   n⋅x    x     ⎟    ⎛ 6⎞
# - ──── + ── + 1⎟ + O⎝x ⎠
#    6     3     ⎠

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>A solution in series form, with 11 terms. It might be interesting to see what a plot would look like (with constants and $\:n\:$ equal to 1).
# </font>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['svg']


x = np.linspace(-10,10,300)
y1 = (x**4/24) + (x**4/12) + (x**4/24) + (x**2/2) - (x**4/4) - \
    (x**2/2) + 1 + x*(-(x**2/6) - (x**2/6) + (x**2/3) + 1)

        
plt.grid(True, linestyle='dotted', color='gray', linewidth=0.9)
plt.xlabel("x")
plt.ylabel("y(x)")
plt.title("Outline of Differential Equations Prob 27.12")
plt.rcParams['figure.figsize'] = [6, 9]

        
ax = plt.gca()
ax.axhline(y=0, color='#993399', linewidth=0.8)
ax.axvline(x=0, color='#993399', linewidth=0.8)
ratio = 0.98
xleft, xright = ax.get_xlim()
ybottom, ytop = ax.get_ylim()
ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)


#plt.text(965, -2.5e43, "-np.log(abs((np.cos(x/2))**2 - (np.sin(x/2))**2)))
#plt.text(965, 2.25e43, "SOLN: y = 3*np.exp(x**2) + 1/2", size=10,\
        # bbox=dict(boxstyle="square", ec=('#8C564B'),fc=(1., 1., 1),))
plt.ylim(-6,3)
plt.xlim(-3, 4)
plt.plot(x, y1, linewidth = 1, color = '#CC6666')
plt.show()

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>27.14 Find a recurrence formula for the differential equation $\:(x^2\,+\,4)\,y\,''\,+\,xy\,=\,x\,+\,2\,$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>A rather difficult problem, apparently. Symbolab will not solve it, sympy will not solve it, and Maxima will not solve it. Only Wolfram Alpha will solve this one, and it is a long solution. However, it does not contain $\,\textsf{erfi}$ or any exotic elements like imaginaries.
#
# The entry line for W|A is:
#
# !| (x^2 + 4) y'' + x y = x + 2 |!
#
# and the result is:
#
# $$y(x)\,=\,c_1\,+\,c_2\,x\,+\,\frac{x^2}{4}\,+\,\left(\frac{1}{24}\,-\,\frac{c_1}{24}\right)\,x^3\,+\,\left(-\frac{c_2}{48}\,-\,\frac{1}{96}\right)\,x^4\,+\,\left(\frac{c_1}{320}\,-\,\frac{1}{160}\right)\,x^5\,+$$
#
# $$\,\left(\frac{c_1}{2880}\,+\,\frac{c_2}{480}\,+\,\frac{1}{1440}\right)\,x^6\,+\,\left(-\frac{c_1}{2688}\,+\,\frac{c_2}{8064}\,+\,\frac{13}{16128}\right)\,x7\,+$$
#
# $$\left(-\frac{13\,c_1}{215040}\,-\,\frac{c_2}{3584}\,-\frac{1}{15360}\right)\,x^8\,+\,\left(\frac{11 c_1}{207360}\,-\,\frac{7\,c_2}{276480}\,-\,\frac{199}{1658880}\right)\,x^9\,+$$
#
# $$\left(\frac{101\,c_1}{9676800}\,+\,\frac{25\,c_2}{580608}\,+\,\frac{229}{29030400}\right)\,x^{10}\,+
# \left(-\frac{97\,c_1}{11354112}\,+\,\frac{113\,c_2}{23654400}\,+\,\frac{401}{20275200}\right)\,x^{11}\,+$$
#
# $$\left(-\frac{2881\,c_1}{1532805120}\,-\,\frac{7451\,c_2}{1021870080}\,-\,\frac{6851}{6131220480}\right)\,x^{12}\,+\,O\left(x^{13}\right)$$
#
# Of course this is only the solution. The recurrence formula would possibly be even more complex to calculate. In keeping with the chapter theme, W|A delivers its solution in series form.
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>27.16 Find the recurrence formula for the power series solution around $\,t\,=\,0\,$ for the nonhomogeneous differential equation $\,(d^2y/dt^2)\,+\,ty\,=\,e^{t\,+\,1}$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The sympy soln below contains Airy function terms. Though the name contains the letter 'i', this is not to be confused with an instance of the imaginary 'i'. This is something different. Symbolab will not solve it, Maxima will not solve it, and the Wolfram Alpha solution is not appetizing. Reliance falls on sympy.
# </font>
# </div>

# %%
import sympy as sp

n = sp.Symbol('n', positive=True, integer=True)
t = sp.Symbol('t')
y = sp.Function('y')(t)
yp = sp.Derivative(y, t)
ydp= sp.Derivative(y, t, t)
equation = sp.Eq(ydp + t*y, sp.exp(t + 1))
display(equation)
# Out:
# Eq(t*y(t) + Derivative(y(t), (t, 2)), exp(t + 1))

# %%
solution = sp.dsolve(equation)
display(solution)
# Out:
# Eq(y(t), C1*airyai(-t) + C2*airybi(-t))

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The above is nice and compact, but there may be an insecure feeling about harboring unevaluated Airy functions in the solution. To correct that, assign 1 to the constants and try
# </font>
# </div>

# %%
from sympy import airyai
from sympy import airybi
from sympy import series
airyai(t)
# Out:
# airyai(t)

# %%
soln = series(airyai(t), t, 0, 1) + series(airybi(t), t, 0, 1)
soln
# Out:
# 3**(1/3)*gamma(1/3)/(2*pi) + 3**(5/6)*gamma(1/3)/(6*pi) + O(t)

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Trading Airy functions for gamma functions, which may or may not be more acceptable. The objective of the problem was to get an evaluation around $\,t\,=\,0\,$, so it may be prudent to get a look at that area. (In the plot below a test coordinate is framed.)
# </font>
# </div>

# %%
soln = airyai(0).evalf(20) + airybi(0).evalf(20)
soln
# Out:
# 0.96995468133381797441

# %%
import numpy as np
from scipy.special import gamma as gm
import sympy as sp
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['svg']

x = np.linspace(-10,10,700)

def f(x):
    return (3**(1/3)*gm(x)*(1/3))/(2*np.pi) + (3**(5/6)*gm(x)*(1/3))/(6*np.pi) 
y = f(x)
yz = f(-0.025)
yw = f(0.025)
ys = f(0.003)

plt.grid(True, linestyle='dotted', color='gray', linewidth=0.9)
plt.xlabel("t")
plt.ylabel("y(t)")
plt.title("Outline of Differential Equations Prob 27.16")
plt.rcParams['figure.figsize'] = [6, 9]
plt.rcParams['font.serif'] = ['Bookerly']
plt.rcParams['mathtext.fontset'] = 'cm'

ax = plt.gca()
#ax.axhline(y=0, color='#993399', linewidth=0.8)
ax.axvline(x=0, color='#993399', linewidth=0.8)
ratio = 0.98
xleft, xright = ax.get_xlim()
ybottom, ytop = ax.get_ylim()
ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)

plt.text(0.8, -2, " ( $\sqrt[3]{3}  \Gamma \, / 6 \pi) + (\sqrt[5/6]{3} \,\Gamma \,/ \,18 \,π) $ ", size=10,\
         bbox=dict(boxstyle="square", ec=('#6666BB'),fc=(1., 1., 1),))
xpts = np.array([-0.025])
ypts = np.array(yz)
wpts = np.array(yw)
plt.plot(xpts, ypts, markersize=7, color='k', marker='s', \
         mfc='none', linestyle = 'none', markeredgewidth=0.5)
#plt.plot(xpts, wpts, markersize=7, color='k', marker='s', \
         #mfc='none', linestyle = 'none', markeredgewidth=0.5)
plt.ylim(-6, 6)
plt.xlim(-6, 6)
plt.plot(x, y, linewidth = 0.7, color = '#6666BB')
plt.show()
print('f(-0.025) = '+str(yz)+'  [framed]')
print('f(0.003) = '+str(ys))
# Out:
# f(-0.025) = -4.9002753218079  [framed]
# f(0.003) = 40.16033714044164

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Above: The function is sensitive to being close to zero. Obviously, f(0) is not defined. Two small values are printed.
#
# Technical note: since it is not feasible to chop a line in the middle of a Latex label, the PDF version may be cut off. The actual full line for the boxed label in the above plot is printed here for reference: " plt.text(0.8, -2, " ( $\sqrt[3]{3}  \Gamma \, / 6 \pi) + (\sqrt[5/6]{3} \,\Gamma \,/ \,18 \,π) $ ", size=10,\
#          bbox=dict(boxstyle="square", ec=('#6666BB'),fc=(1., 1., 1),)) "  .
#
# (Jupyter omits the line-breaking backslash.)
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>27.18 Find the general solution near $\,x\,=\,2\,$ of $\,y\,''\,-\,(x\,-\,2)\,y\,'\,+\,2y\,=\,0\,$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Another difficult problem to solve. Symbolab will not solve it, Maxima will not solve it, and the Wolfram Alpha solution is not alluring, containing the repellent $\,\mathsf{erfi}\,$ function. The sympy resource is sought again.
# </font>
# </div>

# %%
import sympy as sp

n = sp.Symbol('n', positive=True, integer=True)
x = sp.Symbol('x')
y = sp.Function('y')(x)
yp = sp.Derivative(y, x)
ydp= sp.Derivative(y, x, x)
eq = sp.Eq(ydp - (x - 2)*yp + 2*y, 0)
eq
# Out:
# Eq(-(x - 2)*Derivative(y(x), x) + 2*y(x) + Derivative(y(x), (x, 2)), 0)

# %%
soln = sp.dsolve(eq)
soln
# Out:
# Eq(y(x), C2*(-x**4/3 + 2*x**3/3 - x**2 + 1) + C1*x*(-x**3/4 + x**2/2 - x + 1) + O(x**6))

# %%
simplify( -(2**4/3) + (2*2**3/3) - (2**2) + 1) + 2*(-(2**3/4) + (2**2/2) - 2 + 1 )
# Out:
# -5.00000000000000

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>To get a better understanding of the tasking for getting close to $\,x\,=\,2\,$ a plot should be available.
# </font>
# </div>

# %%
import numpy as np
from scipy.special import gamma as gm
import sympy as sp
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['svg']

x = np.linspace(-10,10,300)

#def f(x):
#    return (3**(1/3)*gm(x)*(1/3))/(2*np.pi) + (3**(5/6)*gm(x)*(1/3))/(6*np.pi) 
#y = f(x)

y = -(x**4/3) + (2*x**3/3) - x**2 + 1 + x*(-(x**3/4) + (x**2/2) - x + 1) 

plt.grid(True, linestyle='dotted', color='gray', linewidth=0.9)
plt.xlabel("x")
plt.ylabel("y(x)")
plt.title("Outline of Differential Equations Prob 27.18")
plt.rcParams['figure.figsize'] = [5, 10]
plt.rcParams['font.sans-serif'] = ['Liberation Sans']
plt.rcParams['mathtext.fontset'] = 'cm'

ax = plt.gca()
ax.axhline(y=0, color='#993399', linewidth=0.8)
ax.axvline(x=0, color='#993399', linewidth=0.8)
ratio = 0.98
xleft, xright = ax.get_xlim()
ybottom, ytop = ax.get_ylim()
ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)

plt.text(-1.73, 1.65, "($-(x^4/3)+(2x^3/3)-x^2+1+x((-x^3/4)+(x^2/2-x+1)$",\
         size=10,bbox=dict(boxstyle="square",ec=('#669966'),fc=(1., 1., 1),))
xpts = np.array([2])
ypts = np.array([-5])
plt.plot(xpts, ypts, markersize=7, color='k', marker='s', \
         mfc='none', linestyle = 'none', markeredgewidth=0.5)
plt.ylim(-6, 2)
plt.xlim(-2, 3.5)
plt.plot(x, y, linewidth = 0.9, color = '#669966')
plt.show()

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Nothing special seems to be happening around the point $\,x\,=\,2\,$, so the party will pass on.
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>27.19 Find the general solution near $\,x\,=\,-1\,$ of $\,y\,''\,+\,xy\,'\,+\,(2x\,-\,1)\,y\,=\,0\,$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
#
#
# <font color='blue'>Another difficult problem to solve. Symbolab will not solve it, Maxima will not solve it, and the Wolfram Alpha solution is not inviting, containing the unfamiliar $\,\mathsf{erfi}\,$ function. Aid from sympy is needed again.
# </font>
# </div>

# %%
import sympy as sp

n = sp.Symbol('n', positive=True, integer=True)
x = sp.Symbol('x')
y = sp.Function('y')(x)
yp = sp.Derivative(y, x)
ydp= sp.Derivative(y, x, x)
eq = sp.Eq(ydp + x*yp + (2*x - 1)*y , 0)
eq
# Out:
# Eq(x*Derivative(y(x), x) + (2*x - 1)*y(x) + Derivative(y(x), (x, 2)), 0)

# %%
soln = sp.dsolve(eq)
soln
# Out:
# Eq(y(x), C2*(-x**4/24 - x**3/3 + x**2/2 + 1) + C1*x*(1 - x**3/6) + O(x**6))

# %%
simplify((-1/24) + (1/3) + (1/2) + 1 + -1*(1 + 1/6))
# Out:
# 0.625000000000000

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Above: The solution is evaluated at $\,x\,=\,-1\,$. To get a better understanding of the tasking for getting close to $\,x\,=\,-1\,$ a plot should be available, with the coordinate of interest framed.
# </font>
# </div>

# %%
import numpy as np
from scipy.special import gamma as gm
import sympy as sp
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['svg']

x = np.linspace(-10,10,300)

#def f(x):
#    return (3**(1/3)*gm(x)*(1/3))/(2*np.pi) + (3**(5/6)*gm(x)*(1/3))/(6*np.pi) 
#y = f(x)

y = -(x**4/24) - (x**3/3) + (x**2/2) + 1 + x*(1 - (x**3/6) ) 

plt.grid(True, linestyle='dotted', color='gray', linewidth=0.9)
plt.xlabel("x")
plt.ylabel("y(x)")
plt.title("Outline of Differential Equations Prob 27.19")
plt.rcParams['figure.figsize'] = [7, 6]
plt.rcParams['font.sans-serif'] = ['Liberation Sans']
plt.rcParams['mathtext.fontset'] = 'cm'

ax = plt.gca()
ax.axhline(y=0, color='#993399', linewidth=0.8)
ax.axvline(x=0, color='#993399', linewidth=0.8)
ratio = 0.98
xleft, xright = ax.get_xlim()
ybottom, ytop = ax.get_ylim()
ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)

plt.text(-2,2.5,"$(-x^4/24-x^3/3+x^2/2+1) + x(1-x^3/6)$",size=10,\
         bbox=dict(boxstyle="square", ec=('#BBAA33'),fc=(1., 1., 1),))
xpts = np.array([-1])
ypts = np.array([0.625])
plt.plot(xpts, ypts, markersize=7, color='k', marker='s', \
         mfc='none', linestyle = 'none', markeredgewidth=0.5)
plt.ylim(-1, 3)
plt.xlim(-3, 2.5)
plt.plot(x, y, linewidth = 0.9, color = '#BBAA33')
plt.show()

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The solution function appears uneventful around the point $\,x\,=\,-1\,$, so the problem will be concluded.
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>27.20 Find the general solution near $\,x\,=\,1\,$ of $\,y\,''\,+\,(x - 1)\,y\,=\,e^x\,$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Neither Symbolab nor Maxima will solve the problem. Wolfram Alpha offers a solution with numerous Airy functions and $\xi$ characters. Again, sympy becomes the solver of choice.
# </font>
# </div>

# %%
import sympy as sp
t = sp.symbols('t')
n = sp.Symbol('n', positive=True, integer=True)
x = sp.Symbol('x')
y = sp.Function('y')(x)
yp = sp.Derivative(y, x)
ydp= sp.Derivative(y, x, x)
eq = sp.Eq(ydp + (x - 1)*y , sp.exp(x))
eq
# Out:
# Eq((x - 1)*y(x) + Derivative(y(x), (x, 2)), exp(x))

# %%
soln = sp.dsolve(eq)
soln
# Out:
# Eq(y(x), C1*airyai(1 - x) + C2*airybi(1 - x))

# %%
from sympy import airyai
from sympy import airybi
from sympy import series
airyai(x)
# Out:
# airyai(x)

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The sympy solution is shown above, Airy functions including and consisting of Airy Ai and Bi. If the problem's concern is with the behavior around $\,x\,=\,-1\,$ that would relate to a function argument value of 2.
# </font>
# </div>

# %%
soln = series(airyai(1 - x), x, -1, 1) + series(airybi(1 - x), x, -1, 1)
soln
# Out:
# airybi(2) + airyai(2) + O(x + 1, (x, -1))

# %%
tval = airyai(2).evalf(20) + airybi(2).evalf(20)
tval
# Out:
# 3.3330191304014890894

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The above cell suggests that there is no concern connected to the point $\,x\,=\,-1\,$.
# </font>
# </div>

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['svg']

x = np.linspace(-10,10,300)
ary = []

def f(x):
    for k in x:
        k = sp.airyai(1 - k) + sp.airybi(1 - k)
        ary.append(k)
        
y = f(x)

plt.grid(True, linestyle='dotted', color='gray', linewidth=0.9)
plt.xlabel("x")
plt.ylabel("y(x)")
plt.title("Outline of Differential Equations Prob 27.20")
plt.rcParams['figure.figsize'] = [11, 3]
#plt.rcParams['font.sans-serif'] = ['Liberation Sans']
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

ax = plt.gca()
ax.axhline(y=0, color='#993399', linewidth=0.8)
ax.axvline(x=0, color='#993399', linewidth=0.8)
ratio = 0.95
xleft, xright = ax.get_xlim()
ybottom, ytop = ax.get_ylim()
ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)

plt.text(1,2.5,"$Airy\: Ai\:(1 - x) + Airy\: Bi\:(1 - x)$",size=10,\
         bbox=dict(boxstyle="square", ec=('#55BBDD'),fc=(1., 1., 1),))
xpts = np.array([-1])
ypts = np.array([3.333019])
plt.plot(xpts, ypts, markersize=7, color='k', marker='s', \
         mfc='none', linestyle = 'none', markeredgewidth=0.5)
plt.ylim(-1, 4)
plt.xlim(-3, 10)
plt.plot(x, ary, linewidth = 0.9, color = '#55BBDD')
plt.show()
#print(ary)

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>27.21 Solve the initial-value problem $\,y\,''\,-\,(x\,-\ 2)\,y\,'\,+\,2y\,=\,0;\hspace{0.5 cm}y(2)\,=\,5,\,y\,'(2)\,=\,60\,$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Neither Symbolab nor Maxima will solve the problem. Wolfram Alpha offers a long solution including $\,\mathsf{erfi}\,$ functions. As before sympy remains the solver of choice.
# </font>
# </div>

# %%
import sympy as sp
t, c4, c5, c6 = sp.symbols('t c4, c5, c6')
n = sp.Symbol('n', positive=True, integer=True)
x = sp.Symbol('x')
y = sp.Function('y')(x)
yp = sp.Derivative(y, x)
ydp= sp.Derivative(y, x, x)
eq = sp.Eq(ydp - (x - 2)*yp + 2*y , 0)
eq
# Out:
# Eq(-(x - 2)*Derivative(y(x), x) + 2*y(x) + Derivative(y(x), (x, 2)), 0)

# %%
soln = sp.dsolve(eq)
soln
# Out:
# Eq(y(x), C2*(-x**4/3 + 2*x**3/3 - x**2 + 1) + C1*x*(-x**3/4 + x**2/2 - x + 1) + O(x**6))

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Above: a solution becomes available. And if a particular point in the domain caused curiosity, such as $\,x\,=\,2\,$, it could be investigated as shown below.
# </font>
# </div>

# %%
solu = (-(x**4/3) + (2*x**3/3) - x**2 +1) + x*(-(x**3/4) + (x**2/2) - x + 1) 
solu
# Out:
# -x**4/3 + 2*x**3/3 - x**2 + x*(-x**3/4 + x**2/2 - x + 1) + 1

# %%
solu2 = solu.subs(x , 2)
solu2
# Out:
# -5

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>But the actual purpose of the problem was to handle the IVP part.
# </font>
# </div>

# %%
ics = {y.subs(x, 2): 5, yp.subs(x, 2): 60}
ics
# Out:
# {y(2): 5, Subs(Derivative(y(x), x), x, 2): 60}

# %%
ivp = dsolve(eq, ics=ics)
ivp

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>When the above cell is run, it throws an exception. The message says that it is not possible to solve the ODE with the set of initial conditions which is present. This is something of a setback, because it forces the initiative to Wolfram Alpha, which, at least, is able to solve the IVP. It is now necessary to see if it is possbile to become accustomed to the Wolfram Alpha style of IVP solution, complete with $\,\mathsf{erfi}\,$ function.
#
# The entry line is:
#
# !| solve[[y'' - (x - 2) y' + 2 y = 0], {y(2) = 5, y'(2) = 60}] |!
#
# and the solution is:
#
# $$y(x)\,=\,5\,\left(-3\,\sqrt{2\,\pi}\,(x^2\,-\,4x\,+\,3)\,\textrm{erfi}\,\left(\frac{x\,-\,2}{\sqrt{2}}\right)\,-\,x^2\,+\,4x\,+\,6\,e^{1/2\,(x-2)^2}\,(x\,-\,2)\,-\,3\right)$$
#
# Unfortunately it is not possible to check the answer against the text, since the text answer ends with an ellipsis, and the recurrence pattern is not readily discernible.
#
# The W|A entry line to get the derivative of the solution is:
#
# !| D[5 * (-3 * sqrt(2 * pi) * (x^2 - 4 * x + 3) * erfi((x-2)/sqrt(2)) - x^2 + 4 * x + 6 * exp((1/2) * (x-2)^2) * (x - 2) - 3)] |!
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Pursuing the Wolfram Alpha side of the solution process consists in only a couple of steps. On reconsideration, a route to a solution in sympy is glimpsed. A sequence of steps is documented below.
# </div>

# %%
c1, c2 = sp.symbols('c1 c2')
jaz = c2*(-(x**4/3) + (2*x**3/3) - x**2 + 1) + c1*x*(-(x**3/4) + (x**2/2) - x +1)
jaz
# Out:
# c1*x*(-x**3/4 + x**2/2 - x + 1) + c2*(-x**4/3 + 2*x**3/3 - x**2 + 1)

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>In the above cell the solution equation is copied by hand into a new instance, with a new name. It may have been possible to use the memory-resident version.
# </div>

# %%
jazs = jaz.subs(x, 2)
jazs
# Out:
# -2*c1 - 3*c2

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>In the above cell is an expression giving the values of c1 and c2 in terms of one another. It may be useful later.
# </div>

# %%
jaz2 = jaz.diff(x)
jaz2
# Out:
# c1*x*(-3*x**2/4 + x - 1) + c1*(-x**3/4 + x**2/2 - x + 1) + c2*(-4*x**3/3 + 2*x**2 - 2*x)

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>In the above cell is the differentiated version of the solution equation.
# </div>

# %%
jaz2f = sp.simplify(2*c1*(-(3*2**2/4) +2 -1) + c1*(-(2**3/4) + (2**2/2) -2 + 1) + c2*(-(4*2**3/3)+ 2*2**2 -2*2))
jaz2f
# Out:
# -5.0*c1 - 6.66666666666667*c2

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>In the above cell is an expression evaluating the differentiated solution equation, with c1 and c2 set to 2, to capture the constants at the point $\,x\,=\,2\,$. It is not possible to use the sympy substitution command in this case because, for some reason, it introduces new constants.
# </div>

# %%
eq1 = sp.Eq(-2*c1 - 3*c2 ,5)
eq2 = sp.Eq(-5*c1 - 6.6666666*c2, 60)
res = sp.solve([eq1, eq2], (c1, c2))
res
# Out:
# {c1: -88.0000000000000, c2: 57.0000000000000}

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>There is now enough information to solve for the constant values, which is what happens in the cell above.
# </div>

# %%
jazfin = jaz.subs({c1:-14.0540534, c2: 7.7027022})
jazfin
# Out:
# -2.5675674*x**4 + 5.1351348*x**3 - 7.7027022*x**2 - 14.0540534*x*(-x**3/4 + x**2/2 - x + 1) + 7.7027022

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Above: Installing the constants into the solution equation.
# </div>

# %%
import numpy as np
import sympy as sp
from scipy import special
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['svg']

x = np.linspace(-10,10,300)
y = 5*(-3*np.sqrt(2*np.pi)*(x**2 - 4*x + 3)*special.erfi((x-2)/\
    np.sqrt(2)) - x**2 + 4*x + 6*np.exp((1/2)*(x-2)**2)*(x - 2) - 3)
y1 = 10*(-3*np.sqrt(2*np.pi)*(x - 2)*special.erfi((x-2)/np.sqrt(2)) - \
         x + 6*np.exp((1/2)*(x-2)**2) + 2)
y2 = -2.5675674*x**4 + 5.1351348*x**3 -7.7027022*x**2 -14.0540534*x*\
    (-(x**3/4) + (x**2/2) -x +1) + 7.7027022
y3 = -88*x*(-(3*x**2/4) + x - 1) -88*(-(x**3/4) +(x**2/2) -x + 1) + 57*\
    (-(4*x**3/3) + 2*x**2 - 2*x)


plt.grid(True, linestyle='dotted', color='gray', linewidth=0.9)
plt.xlabel("x")
plt.ylabel("y(x)")
plt.title("Outline of Differential Equations Prob 27.21")
plt.rcParams['figure.figsize'] = [7, 7]
plt.rcParams['font.sans-serif'] = ['Liberation Sans']
plt.rcParams['mathtext.fontset'] = 'cm'

ax = plt.gca()
ax.axhline(y=0, color='#993399', linewidth=0.8)
ax.axvline(x=0, color='#993399', linewidth=0.8)
ratio = 0.07
xleft, xright = ax.get_xlim()
ybottom, ytop = ax.get_ylim()
ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)

textstr = '\n'.join((
    r'Wolfram Alpha $y(x)$ = red',
    r'Wolfram Alpha $dy/dx$ = blue',
    r'sympy $y(x)$ = green',
    r'sympy $dy/dx$ = yellow'))

plt.text(8.5, 20, textstr,size=11,\
         bbox=dict(boxstyle="square", ec=('k'),fc=(1., 1., 1),))
xpts = np.array([2, 2])
ypts = np.array([5, 60])
plt.plot(xpts, ypts, markersize=7, color='k', marker='s', \
         mfc='none', linestyle = 'none', markeredgewidth=0.5)
plt.ylim(-70, 80)
plt.xlim(-3, 8)

plt.plot(x, y, linewidth=0.9, color='#CC4444')
plt.plot(x, y1, linewidth=0.9, color='#5544CC')
plt.plot(x, y2, linewidth=0.9, color='#55DD55')
plt.plot(x, y3, linewidth=0.9, color='#CCCC55')
plt.show()

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Solving an IVP is supposed to focus in on a specific member of a solution family. How Wolfram Alpha and sympy came up with different solutions to the IVP, both of which, superficially at least, seem to qualify, is a condition currently without explanation. Though unrelated to the larger mystery, it should be remembered in the case of sympy, there was a series remainder that was discarded.
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>27.22 $\hspace{1 em}$Solve $\,y\,''\,+\,xy\,'\,+\,(2x - 1)\,y\,=\,0;\hspace{0.5 cm}y(-1)\,=\,2,\,y\,'(-1)\,=\,-2\,$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The current problem is not solvable by sympy, nor by Maxima. Wolfram Alpha can solve it, though the solution is somewhat long. The entry for the solve looks like:
#
# !| solve[[y'' + x y' + (2 x -1) y = 0],{y(-1) = 2, y'(-1) = -2}] |!
#
# and the result looks like:
#
# $$\begin{align}
#   &{y(x)\,=\,e^{-1/2(x-4)x\ -\ 29/2} \,\left( -43 e^{9/2}\,\sqrt{2\pi}\,(x^2\,-\,8x\,+\,15)\,\mathsf{erfi}\,\left(\frac{x\,-\,4}{\sqrt{2}}\right)\,-\,43e^{9/2}\sqrt{2\,\pi}\,\mathsf{erfi}\,\left(\frac{5}{\sqrt{2}}\right)\,+ \right.} \\
#   &{\hspace{3 cm} \left. (x^2\,-\,8x\,+\,15)\,+18\,e^{17}\,(x^2 \,-\,8x\,+\,15)\,+86\,e^{(1/2)(x-5)^2+x}\,(x\,-\,4) \right)}  \\
# \end{align}$$
#
# One thing that would seem sensible would be to get a numerical evaluation of the function at the first initial value coordinate. Unfortunately, this cannot be done in Wolfram Alpha because the number of characters to enter the expression would exceed the number allowed. What can be done is to cut the primary expression into three parts, evaluate each, and then join the numerical results.
#
# ① !| [e^(-(1/2) ((-1) - 4) (-1) - (29/2)) (-43 e^(9/2) sqrt(2 pi) ((-1)^2 - 8 (-1) + 15) erfi(((-1) - 4)/sqrt(2)))] |!
#
# substituting $\,x\,=\,-1\,$ in the above expression equals 431.88324285146157.
#
# ② !| e^(-(1/2) ((-1) - 4) (-1) - (29/2)) (-43 e^(9/2) sqrt(2 pi) erfi(5/sqrt(2)) ((-1)^2 -8 (-1) +15)) |!
#
# substituting $\,x\,=\,-1\,$ in the above expression equals -431.88324285146157.
#
# ③ !| e^(-(1/2) ((-1) - 4) (-1) - (29/2)) (18 e^17 ((-1)^2 - 8 (-1) +15) + 86e^((1/2) ((-1) - 5)^2 + (-1)) ((-1) - 4)) |!
#
# substituting $\,x\,=\,-1\,$ in the above expression equals 2.
#
#
# Therefore the Wolfram Alpha solution meets the first initial condition. Doing the same for the first derivative is not possible in Wolfram Alpha, which declines to show the first derivative. This part of the task can be accomplished by Maxima, as shown below.
#
#
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The main equation for $y(x)$ is broken into three parts by Maxima. The fuchsia coloring in the cell below indicates the factor in common among the three which needs to be distributed over all three parts. At the bottom is the float value for the first section. Details of the second and third sections are similar.
#
#
# </div>

# %% [markdown]
# ![re-27.22t2.svg](attachment:re-27.22t2.svg)

# %% [markdown]
# ![image01] (image01.svg)

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The sum of the three section values for the total value of the derivative at $\,x=\,-1\,$ is:
#
# -948.3016226337268 + -1115.698377366273 + 2062 = -1.999999999999773
#
# very close to the -2 value expected.
#
# </div>

# %%
import numpy as np
import sympy as sp
from scipy import special
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['svg']

x = np.linspace(-5,5,300)
y = np.exp(-(1/2)*(x - 4)*x - (29/2))*(-43*np.exp(9/2)*np.sqrt(2*np.pi)\
            *(x**2 - 8*x + 15)*special.erfi((x-4)/np.sqrt(2)) - 43*np.exp(9/2)*\
            np.sqrt(2*np.pi)*special.erfi(5/np.sqrt(2))*(x**2 - 8*x + 15) + 18*\
            np.exp(17)*(x**2 - 8*x + 15)+ 86*np.exp(((1/2)*(x - 5)**2) + x) * 
            (x -4))
y1 = (-86*np.exp(9/2)*(x**2 - 8*x + 15)*np.exp((x - 4)**2/2) - 43*np.sqrt(2*np.pi)\
            *np.exp(9/2)*special.erfi((x - 4)/np.sqrt(2)) * (2*x - 8) + 18*\
            np.exp(17)*(2*x - 8) - 43*np.sqrt(2)*np.exp(9/2)*np.sqrt(np.pi)*special\
            .erfi(5/np.sqrt(2))*(2*x - 8) + 86*np.exp(x + ((x - 5)**2)/2)\
            *np.log(np.e)*(x - 4)**2 + 86*np.exp(x + (x - 5)**2/2))*np.exp(-((x - 4)\
            *x)/2 - 29/2) + (-x/2 - (x - 4)/2)*(-43*np.sqrt(2*np.pi)*np.\
            exp(9/2)*special.erfi((x - 4)/np.sqrt(2))*(x**2 - 8*x + 15) + 18*\
            np.exp(17)*(x**2 - 8*x + 15) - 43*np.sqrt(2)*np.exp(9/2)*np.sqrt\
            (np.pi)*special.erfi(5/np.sqrt(2))*(x**2 - 8*x + 15) + 86*np.exp\
            (x +((x - 5)**2)/2)*(x - 4))*np.exp(-((x - 4)*x)/2 - 29/2)

plt.grid(True, linestyle='dotted', color='gray', linewidth=0.9)
plt.xlabel("x")
plt.ylabel("y(x)")
plt.title("Outline of Differential Equations Prob 27.22")
plt.rcParams['figure.figsize'] = [7, 7]
plt.rcParams['font.sans-serif'] = ['Liberation Sans']
plt.rcParams['mathtext.fontset'] = 'cm'

ax = plt.gca()
ax.axhline(y=0, color='#993399', linewidth=0.6)
ax.axvline(x=0, color='#993399', linewidth=0.6)
ratio = 0.05
xleft, xright = ax.get_xlim()
ybottom, ytop = ax.get_ylim()
ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)

textstr = '\n'.join((
    r'Wolfram Alpha $y(x)$ = red',
    r'Maxima (W|A) $dy/dx$ = blue',
    ))

plt.text(1, -30, textstr,size=11,\
         bbox=dict(boxstyle="square", ec=('k'),fc=(1., 1., 1),))
xpts = np.array([-1, -1])
ypts = np.array([-2, 2])
plt.plot(xpts, ypts, markersize=7, color='k', marker='s', \
         mfc='none', linestyle = 'none', markeredgewidth=0.5)
plt.ylim(-60, 50)
plt.xlim(-3, 4.6)

plt.plot(x, y, linewidth=0.9, color='#CC4444')
plt.plot(x, y1, linewidth=0.9, color='#5544CC')
plt.show()

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>27.24 $\hspace{1 em}$Use the method outlined in Problem 27.23 to solve $\,y\,''\,-\,2xy\,=\,0;\hspace{0.5 cm}y(2)\,=\,1,\,y\,'(2)\,=\,0\,$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem is a step full into Airyland. The entry line in Wolfram Alpha is:
#
# !| solve[[y'' - 2 x y = 0],{y(2) = 1, y'(2) = 0}] |!
#
# and the return is:
#
# $$y(x) \,=\,\small\mathsf{\frac{Ai'(2\,\sqrt[3]{2})\,Bi\,(\sqrt[3]{2}\,x)\,-\,Bi'\,(2\,\sqrt[3]{2})\,Ai\,(\sqrt[3]{2}\,x)}{Ai'\,(2\,\sqrt[3]{2})\,Bi\,(2\,\sqrt[3]{2}\,)\,-\,Ai\,(2\sqrt[3]{2}\,)\,Bi'\,(\,2\sqrt[3]{2}\,)}}$$
#
# On substituting the value $x\,=\,2$, W|A compliantly produces the value 1, in agreement with the first initial condition.
#
# Wolfram Alpha is also ready to provide a derivative for the above equation (if care is taken in putting in the entry):
#
# !|  D[(Ai' (2 2^(1/3)) Bi (2^(1/3) x) - Bi' (2 2^(1/3)) Ai (2^(1/3) x))/(Ai' (2 2^(1/3)) Bi (2 2^(1/3)) - Ai (2 2^(1/3)) Bi' (2 2^(1/3)))] |!
#
# for which the answer is:
#
# $$y\,'(x) \,=\,\sqrt[3]{2}\,\pi \left( \mathsf{Bi'} \left( 2\sqrt[3]{2} \right) \mathsf{Ai'}\left(\sqrt[3]{2}x\right)\,-\, \mathsf{Ai'} \left(2 \sqrt[3]{2} \right) \mathsf{Bi'}\left(\sqrt[3]{2} x\right)\right)$$
#
# (The above is listed as an alternate form of the answer, and is the shortest version of three.)
#
# It is possible to check the second initial condition within W|A inself. The front and back ends of the input above are changed slightly, so that the entire line reads:
# !| ReplaceAll[ D[(Ai' (2 2^(1/3)) Bi (2^(1/3) x) - Bi' (2 2^(1/3)) Ai (2^(1/3) x))/(Ai' (2 2^(1/3)) Bi (2 2^(1/3)) - Ai (2 2^(1/3)) Bi' (2 2^(1/3)))] , {x->2}] |!
#
# And $0$ is returned as the answer, verifying the second initial condition.
#
# Also included in Wolfram Alpha's response page is a small plot. The small plot for the derivative $y'(x)$ does not look like anything which is easily achievable in matplotlib or Maxima. It is shown below.
#
#
#
#
# </font>
# </div>

# %% [markdown]
# ![Image01] (https://github.com/whiffee/Outline_of_Differential_Equations/blob/Chapter-27/image01.png)

# %% [markdown]
# ![WA2.svg](attachment:WA2.svg)

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The first plot will be a naïve execution, in matplotlib, of the two Wolfram Alpha solutions.
#
#
# </font>
# </div>

# %%
import numpy as np
import sympy as sp
from sympy import airyai
from sympy import airybi
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['svg']

x = sp.symbols('x')

x1 = (sp.diff(sp.airyai(x))*2*2**(1/3)*airybi(x)*2**(1/3)*x - \
          sp.diff(sp.airybi(x))*2*2**(1/3)*airyai(x)*2**(1/3)*x)/\
          (sp.diff(sp.airyai(x))*2*2**(1/3)*airybi(x)*2*2**(1/3) - \
          sp.airyai(x)*2*2**(1/3)*sp.diff(airybi(x))*2*2**(1/3))

x2 = 2**(1/3)*sp.pi*(sp.diff(sp.airybi(x))*2*2**(1/3)*sp.diff(sp.airyai(x))*2**(1/3)*x -\
          sp.diff(sp.airyai(x))*2*2**(1/3)*sp.diff(sp.airybi(x))*2**(1/3)*x)
          
            
xt = np.arange(0, 4, 0.01)
yt1 = np.zeros(len(xt))
yt2 = np.zeros(len(xt))

for n in range(0,len(xt)):
    yt1[n] = sp.N(x1.subs(x, xt[n]))
    yt2[n] = sp.N(x2.subs(x, xt[n]))
    
plt.grid(True, linestyle='dotted', color='#999999', linewidth=0.9)
plt.xlabel("x")
plt.ylabel("y(x)")
plt.title("Outline of Differential Equations Prob 27.24")
plt.rcParams['figure.figsize'] = [5,5]
plt.rcParams['font.serif'] = ['Bookerly']
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

ax = plt.gca()
ax.axhline(y=0, color='#CCCCCC', linewidth=0.7)
ax.axvline(x=0, color='#CCCCCC', linewidth=0.7)
ratio = 0.98
xleft, xright = ax.get_xlim()
ybottom, ytop = ax.get_ylim()
ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)

plt.text(0.5, 1.3, " y(x) ", size=10,\
         bbox=dict(boxstyle="square", ec=('#6666BB'),fc=(1., 1., 1),))
plt.text(0.5, -0.75, " y'(x) ", size=10,\
         bbox=dict(boxstyle="square", ec=('#CC6666'),fc=(1., 1., 1),))
xpts = np.array([2, 2])
ypts = np.array([1, 0])
plt.plot(xpts, ypts, markersize=7, color='k', marker='s', \
         mfc='none', linestyle = 'none', markeredgewidth=0.5)
plt.ylim(-2, 4)
plt.xlim(-2, 5)
plt.plot(xt, yt2, linewidth = 0.9, color = '#CC6666')
plt.plot(xt, yt1, linewidth = 0.9, color = '#6666BB')
plt.show()

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Above: The plots hit the initial value points, but are devoid of character because of cancellations.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>It may help to use sympy here.
#
# </font>
# </div>

# %%
import sympy as sp
from sympy import airyai
from sympy import airybi
x, c1, c2 =sp.symbols('x c1 c2')
y =sp.Function('y')(x)
yp = sp.Derivative(y, x)
ydp = sp.Derivative(y, x, x)
ode = sp.Eq(ydp - 2*x*y , 0)
ode
# Out:
# Eq(-2*x*y(x) + Derivative(y(x), (x, 2)), 0)

# %%
sol = sp.dsolve(ode, y)
sol
# Out:
# Eq(y(x), C1*airyai(2**(1/3)*x) + C2*airybi(2**(1/3)*x))

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Then going back to Wolfram Alpha to get the derivative, with the input
#
# !| D[c1 Ai(x) 2^(1/3) + c2 Bi(x) 2^(1/3)] |!
#
# for which the answer is returned:
#
# $\normalsize{\frac{\partial}{\partial x}}\small{\left( c1 \,\textsf{Ai}(x) \,\sqrt[3]{2}\,+\,c2 \,\textsf{Bi}(x)\,\sqrt[3]{2} \right)} \,=\, \sqrt[3]{2}\,\left(c1\,\textsf{Ai}'(x)\,+\,c2\,\textsf{Bi}'(x)\right)$
#
# In other words the derivative form is simple and the constants are preserved. It only remains to find out what those constants are.
# </font>
# </div>

# %%
tval = airyai(2).evalf(15)*(2**(1/3))
tval
# Out:
# 0.0440016470695573

# %%
tval = airybi(2).evalf(15)*(2**(1/3))
tval
# Out:
# 4.15533931502558

# %%
tvalp = airyaiprime(2).evalf(15)*(2**(1/3))
tvalp
# Out:
# -0.0668896928949713

# %%
tvalp = airybiprime(2).evalf(15)*(2**(1/3))
tvalp
# Out:
# 5.16653563363651

# %%
from sympy import *

c1, c2 = symbols('c1 c2')
eq1 = Eq(0.0440016470695573*c1 + 4.15533931502558*c2, 1)
eq2 = Eq(-0.0668896928949713*c1 + 5.16653563363651*c2, 0)
res = solve([eq1, eq2], (c1, c2))
print(res)
# Out:
# {c1: 10.2249840209048, c2: 0.132380010419654}

# %%
import numpy as np
import sympy as sp
from sympy import airyai
from sympy import airybi
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['svg']

x = sp.symbols('x')
x2 = 10.2249840209048*2**(1/3)*airyai(x) + 0.132380010419654*2**(1/3)*airybi(x)
x4 = 10.2249840209048*2**(1/3)*sp.diff(airyai(x)) + 0.132380010419654*2**(1/3)*sp.diff(airybi(x))

xt = np.arange(-8, 4, 0.01)
yt2 = np.zeros(len(xt))
yt4 = np.zeros(len(xt))

for n in range(0,len(xt)):
    yt2[n] = sp.N(x2.subs(x, xt[n]))
    yt4[n] = sp.N(x4.subs(x, xt[n]))
    
plt.grid(True, linestyle='dotted', color='gray', linewidth=0.9)
plt.xlabel("x")
plt.ylabel("y(x)")
plt.title("Outline of Differential Equations Prob 27.24")
plt.rcParams['figure.figsize'] = [7, 10]
plt.rcParams['font.serif'] = ['Bookerly']
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

ax = plt.gca()
ax.axhline(y=0, color='#993399', linewidth=0.7)
ax.axvline(x=0, color='#993399', linewidth=0.7)
ratio = 0.98
xleft, xright = ax.get_xlim()
ybottom, ytop = ax.get_ylim()
ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)

plt.text(0, -4.7, " ( $C_1\:Airy \: Ai' + C_2 \: Airy \: Bi'\:) $ ", size=10,\
         bbox=dict(boxstyle="square", ec=('#6666BB'),fc=(1., 1., 1),))
plt.text(-1.2, 7.5, " ( $C_1\: Airy \:Ai + C_2 \:Airy \:Bi) $ ", size=10,\
         bbox=dict(boxstyle="square", ec=('#CC6666'),fc=(1., 1., 1),))
xpts = np.array([2, 2])
ypts = np.array([1, 0])
plt.plot(xpts, ypts, markersize=7, color='k', marker='s', \
         mfc='none', linestyle = 'none', markeredgewidth=0.5)
plt.ylim(-14, 14)
plt.xlim(-8, 5)
plt.plot(xt, yt2, linewidth = 0.9, color = '#CC6666')
plt.plot(xt, yt4, linewidth = 0.9, color = '#6666BB')
plt.show()

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Though it looks like the functions go right through the center of the initial value frames, it is possible to check to see how closely they come to the sought values. For the $y(x)$ solution equation:
# </font>
# </div>

# %%
y = 10.2249840209048*2**(1/3)*airyai(x) + 0.132380010419654*2**(1/3)*airybi(x)
ys = y.evalf(15, subs={x: 2.000})
ys
# Out:
# 1.00000000000000

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>And for the $y'(x)$ solution equation:
# </font>
# </div>

# %%
yp = 10.2249840209048*2**(1/3)*airyaiprime(x) + 0.132380010419654*2**(1/3)*airybiprime(x)
yps = yp.evalf(15, subs={x: 2.000})
yps
# Out:
# 3.47852624393798e-15

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>In other words, they are pretty accurate.
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Wolfram Mathworld has the series expressions for the Airies, so, in keeping with the theme of the chapter (series form solutions), the answer for $y(x)$ is:
#
# $$y(x) \,=\, C_1\sqrt[3]{2x}\left( \frac{1}{3^{2/3}\pi}\sum_{n=0}^{\infty}\frac{\Gamma \left(\frac{1}{3}(n+1)\right)}{n!}\right)\left( 3^{1/3}\,z\right)^n\:\textrm{sin}\left[ \frac{2\,(n+1)\,\pi}{3}\right]\:+$$
#
# $$\hspace{1.2 cm}C_2\sqrt[3]{2x}\left( \frac{1}{3^{1/6}\pi}\sum_{n=0}^{\infty}\frac{\Gamma \left(\frac{1}{3}(n+1)\right)}{n!}\right)\left( 3^{1/3}\,z\right)^n\:\left| \textrm{sin}\left[ \frac{2\,(n+1)\,\pi}{3}\right]\right|$$
#
# </font>
# </div>
