# %%
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# <div style="background: #DDE2FF;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 20px 5px 0px 5px;
#             border: 10px solid #DDE2FF;
#             margin-left: 1px;
#             margin-right: 1px;"
#
#  <font color='blue'>**Chapter 22 Inverse Laplace Transform**. Introduction to a the system for accomplishing the return from the frequency domain back to the time domain. Up to this point, and including this chapter, there are no problems which involve a complete round trip through both transforms.<br><br>
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.1 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large\frac{1}{s}\right\}$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| inverselaplacetransform[1/s] |!<br>
#
# Result<br>
# 1
#
# At first entry Wolfram Alpha interprets this as a $unit$, (i.e. $per \:\:second$), not as a $variable$. By toggling the highlighted label, the correct interpretation is reached, and the correct answer is dispensed.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.2 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large\frac{1}{s-8}\right\}$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| inverselaplacetransform[1/(s - 8)] |!<br>
#
# Result<br>
# $e^{8t}$
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.3 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large\frac{s}{s^2+6}\right\}$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| expand[inverselaplacetransform[s/(s^2 -+ 6)]] |!<br>
#
# Result<br>
# $\textrm{cos}\,(\sqrt{6}\,t)$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.4 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large\frac{5s}{(s^2+1)^2}\right\}$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| simplify[inverselaplacetransform[5 s/(s^2 + 1)^2]] |!<br>
#
# Result<br>
# $\large \frac{5t}{2}\,\small \textrm{sin}\,(t) \,$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.5 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large\frac{1}{\sqrt{s}}\right\}$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| inverselaplacetransform[1/sqrt(s)] |!<br>
#
# Result<br>
# $\large \frac{1}{\sqrt{\pi}\sqrt{t}}\,\normalsize \,$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"m
#
# <font color='blue'>22.6 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large\frac{s\,+\,1}{s^2\,-\,9}\right\}$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| simplify[inverselaplacetransform[(s + 1)/(s^2 - 9)]] |!<br>
#
# Result<br>
# $\large \frac{1}{3} \small \textrm{sinh}\,(3t)\,+\, \textrm{cosh}\,(3t) \,$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"m
#
# <font color='blue'>22.7 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large\frac{s}{(s\,-\,2)^2\,+\,9}\right\}$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| simplify[inverselaplacetransform[s/((s - 2)^2 + 9)]] |!<br>
#
# Result<br>
# $\large \frac{1}{3} \small e^{2t} \,(2\,\textrm{sin}\,(3t)\,+\,3\,\textrm{cos}\,(3t)) \,$
#
# Using the keyword 'simplify' caused W|A to present the results in 3 different factor groupings, the simplest of which was chosen above.
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"m
#
# <font color='blue'>22.8 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large\frac{1}{s^2\,-\,2s\,+\,9}\right\}$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| inverselaplacetransform[1/(s^2 - 2 s + 9)] |!<br>
#
# Result<br>
# $\large \frac{1}{\sqrt{8}}\,\small e^x\,\textrm{sin}\,\sqrt{8}\,x \,$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"m
#
# <font color='blue'>22.9 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large\frac{s\,+\,4}{s^2\,+\,4s\,+\,8}\right\}$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| simplify[inverselaplacetransform[(s + 4)/(s^2 + 4 s +8)]] |!<br>
#
#
# Result<br>
# $e^{-2t}(\textrm{sin}\,(2t)\,+\,\textrm{cos}\,(2t)) \,$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.10 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large\frac{s\,+\,2}{s^2\,-\,3s\,+\,4}\right\}$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| simplify[inverselaplacetransform[(s + 2)/(s^2 -3 s + 4)]] |!<br>
#
#
# Result<br>
# $e^{3t/2}\,\small \left(\sqrt{7}\,\textrm{sin}\normalsize \left(\frac{\sqrt{7}\,t}{2}\right)\,\small+\,\textrm{cos}\normalsize \left(\frac{\sqrt{7}\,t}{2}\right)\right) \,$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.11 Use partial fractions to decompose $\large \frac{1}{(s\,+\,1) (s^2 \, +\,1)}$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| Apart[1/((s + 1) (s^2 +1))] |!<br>
#
#
# Result<br>
#
# $\large \frac{1\,-\,s}{2(s^2+\,1)}\small +\,\large \frac{1}{2(s\,+\,1)} \,$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.12 Use partial fractions to decompose $\large \frac{1}{(s^2\,+\,1) (s^2 \, +\,4s\,+\,8)}$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| Apart[1/((s^2 + 1) (s^2 +4 s + 8))] |!<br>
#
#
# Result<br>
#
# $\large \frac{7\,-\,4s\,}{65(s^2+\,1)}\small +\,\large \frac{4s\,+\,9}{65(s^2\,+\,4s\,+\,8)} \,$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.13 Use partial fractions to decompose $\large \frac{s\,+\,3}{ (s \, -\,2)(s\,+\,1)}$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| Apart[(s + 3)/((s - 2) ( s + 1))] |!<br>
#
#
# Result<br>
#
# $\large \frac{5}{3\,(s\,-\,2)}\small -\,\large \frac{2}{3\,(s\,+\,1\,} \,$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.14 Use partial fractions to decompose $\large \frac{8}{ s^3\,(s^2 \, -\,s\,-\,2)}$.<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| Apart[8/(s^3 (s^2 - s - 2))] |!<br>
#
#
# Result<br>
#
# $-\large \frac{4}{s^3}\,\small+\,\large \frac{2}{s^2}\,\small - \,\large \frac{3}{s}\,\small + \,\large \frac{8}{3\,(s\,+\,1)}\small +\,\large \frac{1}{3\,(s\,-\,2)} \,$
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.15 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large \frac{s\,+\,3}{(s - 2)\,(s + 1)}\right\}\,$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| inverselaplacetransform[(s + 3)/ ((s - 2)(s + 1))] |!<br>
#
#
# Result<br>
#
# $\large \frac{1}{3}\,\small e^{-t}\,(5\,e^{3t}\,-\,2)\,$
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.16 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large \frac{8}{s^3(s^2 \,- \,s\, -\,2)}\right\}\,$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| inverselaplacetransform[8/(s^3 (s^2 - s - 2))] |!<br>
#
#
# Result<br>
#
# $8\large \left(\small-\large\frac{t^2}{4}\small\,+\,\large\frac{t}{4}\small\,+\,\large\frac{e^{-t}}{3}\small\,+\,\large\frac{e^{2t}}{24}\small\,-\,\large\frac{3}{8}\right)\,$
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.17 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large \frac{1}{(s \,+\,1)\,(s^2 \,+ \,1\, )}\right\}\,$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| inverselaplacetransform[1/((s + 1) (s^2 + 1))] |!<br>
#
#
# Result<br>
#
# $\,\large \frac{e^{-t}}{2}\small \,+ \,\large \frac{1}{2}\,\small(\textrm{sin}\,(t)\,-\,\textrm{cos}\,(t))\,$
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.18 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large \frac{1}{(s^2 \,+\,1)\,(s^2 \,+ \,4s\, +\,8)}\right\}\,$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| simplify[inverselaplacetransform[1/((s^2 + 1) (s^2 + 4 s + 8))]] |!<br>
#
#
# Result<br>
#
# $\,\large \frac{1}{130}\small (14\,\textrm{sin}\,(t)\,-\,8\,\textrm{cos}\,(t)\,+\,e^{-2t}\,(\textrm{sin}\,(2t)\,+\,8\,\textrm{cos}\,(2t)))\,$
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>22.19 Find $\hspace{0.5 cm}\mathscr{L}^{-1}\left\{\large \frac{1}{s\,(s^2 \,+\,4)}\,\right\}\,$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| simplify[inverselaplacetransform[1/(s (s^2 + 4))]] |!<br>
#
#
# Result<br>
#
# $\,\large \frac{1}{4}\,\small (1\,-\,\textrm{cos}\,(2t))$
#
#
#
#
# </font>
# </div>
