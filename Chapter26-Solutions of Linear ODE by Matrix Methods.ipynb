# %%
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# <div style="background: #DDE2FF;
#             font-family: Bookerly;
#             font-size: 14px;
#             font-weight: 500;
#             padding: 30px 5px 30px 5px;
#             border: 30px solid #DDE2FF;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>(Custom CSS files are not reliable for controlling Jupyter font style. To establish the same appearance as the original notebook, depend on the browser to control the font, by setting the desired font faces in the browser settings. For example, Chrome 135 or Firefox 134 can do this. In this notebook series, Bookerly font is for markdown and Monaco is for code.)
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #DDE2FF;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 20px 5px 20px 5px;
#             border: 30px solid #DDE2FF;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>$\textbf{ Chapter 26: Solutions of Linear Differential Equations w Constant Coefficients}$
# $\textbf{by Matrix Methods}$. Learning to handle differential equations according to matrix principles, and to transmute equations into that format.<br><br>
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Note: When transcribing text for entry into Wolfram Alpha the "fenceposts" !| ... |! are excluded from the text.
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Starting with the example equation: $\hspace{0.5 cm}t^4\large \frac{d^2x}{dt^2}\,\small +\, (\textrm{sin}\,t)\,\large \frac{dx}{dt}\,\small -\,4\,x\,=\,\textrm{log}\,t$<br>
#
# It is not difficult to rearrange to isolate the second order derivative on lhs:
#
# $$ \frac{d^2x}{dt^2}\,=\,\small -\,\frac{(\textrm{sin}\,t)}{t^4}\,\frac{dx}{dt}\,\small +\,\frac{4\,x}{t^4}\,+\,\frac{\textrm{log}\,t}{t^4}$$
#
# Then suppose $ \,v\,=\,x'\hspace{1em}$ and $\hspace{1 em}\,v'\,=\,x'' $. A matrix multiplication could be arranged whereby, as shown in the sympy cell below,
#
#
#
# </font>
# </div>

# %%
from sympy import *

t, v, x, xprime, vprime = symbols('t v x xprime vprime')
pr = Matrix(2, 1, (xprime, vprime))
asy = Matrix(2, 2, [0, 1, 4/t**4, -sin(t)/t**4])
vp = Matrix(2, 1, [x, v])
ex = Matrix(2, 1, [0, log(t)/t**4])
res = asy*vp + ex

pr
# Out:
# Matrix([
# [xprime],
# [vprime]])

# %%
asy
# Out:
# Matrix([
# [     0,            1],
# [4/t**4, -sin(t)/t**4]])

# %%
ex
# Out:
# Matrix([
# [          0],
# [log(t)/t**4]])

# %%
pr = asy*vp + ex
pr
# Out:
# Matrix([
# [                                      v],
# [-v*sin(t)/t**4 + 4*x/t**4 + log(t)/t**4]])

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The above two cells show a basic matrix representation of an ODE and its solution. And the paradigm of solving ODEs via linear algebra methods could be developed, which is exactly what this chapter is intended to do. However, since most system equation goals can be achieved through Laplace methods, as shown in the last chapter, this, at least for now, will be another derailed chapter. Only if some equation cannot be operated on by routine plugging, or by trial of a Laplace procedure, will the prospect of matrices be revisited.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 20px 5px 20px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>26.1 Solve $\,\ddot{x}\,+\,2\dot{x}\,-\,8x\,=\,0;\hspace{0.5 cm}x(1)\,=\,2,\,\dot{x}\,(1)\,=\,3$.
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered in Wolfram Alpha. The entry line is:
#
# !| [x'' + 2 x' - 8 x = 0; {x(1) = 2, x'(1) = 3}] |!
#
# and the result is:
#
# $$x(t)\,=\,\frac{1}{6}\,e^{-4t-2}\,(11e^{6t}\,+\,e^6)$$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 20px 5px 20px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>26.2 $ \hspace{1 em}$ Solve $\,\ddot{x}\,+\,2\dot{x}\,-\,8x\,=\,e^t;\hspace{0.5 cm}x(0)\,=\,1,\,\dot{x}\,(0)\,=\,-4$.
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered in Wolfram Alpha. The entry line is:
#
# !| [x'' +2 x' - 8 x = e^t, {x(0) = 1, x'(0) = -4}] |!
#
# and the result is:
#
# $$x(t)\,=\,\frac{1}{30}\,e^{-4t}\,(-6e^{5t}\,+\,5e^{6t}\,+\,31)$$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 20px 5px 20px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>26.4 $ \hspace{1 em}$ Solve $\,\ddot{x}\,+\,x\,=\,3;\hspace{0.5 cm}x(\pi)\,=\,1,\,\dot{x}\,(\pi)\,=\,2$.
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered in Wolfram Alpha. The entry line is:
#
# !| [x'' + x = 3, {x(pi) = 1, x'(pi) = 2}] |!
#
# and the result is:
#
# $$x(t)\,=\,-\,2\,\textrm{sin}\,(t)\,+\,2\,\textrm{cos}\,(t)\,+\,3$$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 20px 5px 20px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>26.5 $ \hspace{1 em}$ Solve the differential equation $\,\ddot{x}\,-\,6\dot{x}\,+\,9x\,=\,t$.
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered in Wolfram Alpha. The entry line is:
#
# !| [x'' - 6 x' + 9 x = t] |!
#
# and the result is:
#
# $$x(t)\,=\,c_2\,e^{3t}t\,+\,c_1\,e^{3t}\,+\,\frac{t}{9}\,+\,\frac{2}{27}$$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 15px 5px 10px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>26.6 $ \hspace{1 em}$ Solve the differential equation $\,\large\frac{d^3x}{dt^3}\,\small-\,2\large \frac{d^2v}{dt^2}\,\small +\,\large \frac{dx}{dt}\,\small =\,0$.
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered in Wolfram Alpha. The entry line is:
#
# !| d^3x/dt^3 -2 x'' + x' = 0 |!
#
# and the result is:
#
# $$x(t)\,=\,e^t\,(c_2t\,+\,(c_1\,-\,c_2))\,+\,c_3$$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 15px 5px 10px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>26.7 $ \hspace{1 em}$ Solve the system
#
# $$\,\ddot{x}\,=\,-\,2\dot{x}\,-\,5\,y\,+\,3$$
#
# $$\dot{y}\,=\,\dot{x}\,+\,2y;$$
#
# $$x(0)\,=\,0\hspace{0.7 cm}\dot{x}(0)\,=\,0\hspace{0.7 cm}y(0)\,=\,1$$
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Wolfram Alpha will not process this problem, either as a direct ODE or as an input to a Laplace transform. Therefore Maxima will have to do the initial work. The two cells below show the individual equations for both parts of the system of equations. The lines corresponding to entry into Laplaceland are numbers 6 and 15.
#
# </font>
# </div>

# %% [markdown]
# ![image01-1.svg](attachment:image01-1.svg)

# %% [markdown]
# <img src="image01-2.svg"/>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The s-algebraic equations are the cleaned-up versions of the ones shown in the raw Maxima cells. They are displayed below.
#
# $$5\, Y(s)\,+\,s^2\,X(s)\,+\,2s X(s)\,=\,\frac{3}{s}$$
#
# $$\,s \,Y(s)\,-\,1\,=\,2\,Y(s)\,+\,s\,X(s)$$
#
# The algebraic step of the Laplace method is to get the two above equations solved simultaneously. This will be done in Wolfram Alpha, with the entry line:
#
# !| solve[5 y + s^2 x + 2 s x = 3/s, s y -1 =2 y + s x], x, y |!
#
# and having the result:
#
# $$x \,=\,-\frac{2\,(s\,+\,3)}{s^4\,+\,s^2}$$
#
# $$y\,=\,\frac{s^2\,+\,2\,s\,+\,3}{s^3\,+\,s}$$
#
# The two equations above are now staged and ready to return to Regularland, via Wolfram Alpha. The entry line for the first is:
#
# !| inverse laplace transform[-(2s + 6)/(s^4 + s^2), s, t] |!
#
# and the result is:
#
# $$-6\,t\,+\,2\,(3\,\textrm{sin}\,(t)\,+\,\textrm{cos}\,(t))\,-\,2$$
#
# and the second entry line is:
#
# !| inverse laplace transform[(s^2 + 2s + 3)/(s^3 + s), s, t] |!
#
# and the result is:
#
# $$2\,\textrm{sin}\,(t)\,-\,2\,\textrm{cos}\,(t)\,+\,3$$
#
# In Regularland, $x$ symbols will be inserted to replace the $s$ symbols, and the problem will be complete. The problem admitted application of the Laplace method, resulting in a much shorter workspace. Of course this is not guaranteed to always be the case.
#
#
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 15px 5px 10px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>26.8 $ \hspace{1 em}$ Solve the system of differential equations
#
# $$\,\dot{x}\,=\,x\,+\,y$$
#
# $$\dot{y}\,=\,9x\,+\,y$$
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Wolfram Alpha has no difficulty solving this problem, with the input line:
#
# !| solve[{x' = x + y, y' = 9 x + y}] |!
#
# and the results:
#
# $$x(t) = \frac{1}{2}\,c_1\,e^{-2t}\,(e^{6t}\,+\,1)\,+\,\frac{1}{6}\,c_2\,e^{-2t}\,(e^{6t}\,-\,1)$$
#
# $$y(t)\,=\,\frac{3}{2}\,c_1\,e^{-2t}\,(e^{6t}\,-\,1)\,+\,\frac{1}{2}\,c_2\,e^{-2t}\,(e^{6t}\,+\,1)$$
#
# Because of the complicated nature of these answers, it may be best to reconcile them with the text answer by drawing a plot. (In the plots, all arbitrary constants are assigned the value of 1.)
# </font>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['svg']

x = np.linspace(-10,10,300)
y3 = (1/2)*np.exp(-2*x)*(np.exp(6*x) + 1) + (1/6)*np.exp(-2*x)*(np.exp(6*x) - 1)
y4 = (3/2)*np.exp(-2*x)*(np.exp(6*x) - 1) + (1/2)*np.exp(-2*x)*(np.exp(6*x) + 1)
# the two functions above were calculated by Wolfram Alpha
y5 = (1/6)*(3 + 1)*np.exp(4*x) + (1/6)*(3 - 1)*np.exp(-2*x)
y6 = (3/6)*(3 + 1)*np.exp(4*x) - (3/6)*(3 - 1)*np.exp(-2*x)
# the two functions above were calculated by the text

        
plt.grid(True, linestyle='dotted', color='gray', linewidth=0.9)
plt.xlabel("t")
plt.ylabel("y(t) / x(t)")
plt.title("Outline of Differential Equations Prob 26.8")
plt.rcParams['figure.figsize'] = [9, 7.5]

        
ax = plt.gca()
ax.axhline(y=0, color='#993399', linewidth=0.8)
ax.axvline(x=0, color='#993399', linewidth=0.8)
ratio = 0.5
xleft, xright = ax.get_xlim()
ybottom, ytop = ax.get_ylim()
ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)


#plt.text(965, -2.5e43, "-np.log(abs((np.cos(x/2))**2 - (np.sin(x/2))**2)))
#plt.text(965, 2.25e43, "SOLN: y = 3*np.exp(x**2) + 1/2", size=10,\
        # bbox=dict(boxstyle="square", ec=('#8C564B'),fc=(1., 1., 1),))
plt.ylim(-2,15)
plt.xlim(-3, 2)
plt.plot(x, y3, linewidth = 3, color = '#AA6666')
plt.plot(x, y4, linewidth = 3, color = '#666699')
plt.plot(x, y5, linewidth = 0.9, color = 'w')
plt.plot(x, y6, linewidth = 0.9, color = 'w')
plt.show()
