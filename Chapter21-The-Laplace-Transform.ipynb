# %% [markdown]
# <div style="background: #DDE2FF;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 20px 5px 0px 5px;
#             border: 10px solid #DDE2FF;
#             margin-left: 1px;
#             margin-right: 1px;"
#
#  <font color='blue'>**Chapter 21 The Laplace Transform**. Introduction to a far reaching system for simplification of the ODE solving process. The transform is from the time domain to the frequency domain, where algebraic operations are performed before inverse transportation back to the time domain. The main variable governing the frequency domain is $s$, and the time domain $t$.<br><br>
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.1 Determine whether the improper integral<br>
#
# $$\int_2^{\infty}\frac{1}{x^2}\, dx$$
#
# converges.
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| integrate[1/x^2 dx] from 2 to infinity |!<br>
#
# In Wolfram Alpha the expression is merely referred to as a "Definite integral":
#
# $$\int_x^\infty \frac{1}{x^2}\,dx\,=\,\frac{1}{2}\,=\,0.5$$
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.2 Determine whether the improper integral<br>
#
# $$\int_9^{\infty}\frac{1}{x}\, dx$$
#
# converges.
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| integrate[1/x dx] from 9 to infinity |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result (integral does not converge)
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.3 Determine those values of $s$ for which the improper integral<br><br>
#
# $$\int_0^{\infty} e^{-sx}\, dx$$
#
# converges.
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| integrate[e^(-s * x) dx] from 0 to infinity |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Definite integral
# $\int_0^\infty\,e^{-sx}\,dx\,=\,\large\frac{1}{s}\,$ for Re$(s)\,>0$
#
# So relying on Wolfram Alpha to set restrictive conditions works in this case.
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.4 Find the Laplace transform of $f(x)\,=\,1$.
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| find laplace transform of [1] |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result
# $\large \frac{1}{s}$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.5 Find the Laplace transform of $f(x)\,=\,x^2$.
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| find laplace transform of [x^2] |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result
# $\large \frac{2}{p^3}$
#
# In Laplaceland the focused-on entity is usually referred to as $s$, but some some reason that differs here. The $p$ comes from the standard notation of the transform operator,
#
# $$\mathscr{L}\,[f(x)]\,=\,\int_0^x\,e^{-p\,x}\,f(x)\,dx$$
#
# In comparing the answers to problems in this Chapter, it is evident that the $s$ and $p$ styles of representation are interchangeable.
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.6 Find $\hspace{0.5 cm}\mathscr{L}\{ e^{ax} \}$.
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| find laplace transform of [e^(ax)] |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result
# $\large \frac{1}{p\,-\,a}$
#
# Focusing on $p$ here, as noted above.
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.7 Find $\hspace{0.5 cm}\mathscr{L}\{ \textrm{sin}\,ax \}$.
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| find laplace transform of [sin(ax)] |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result
# $\large \frac{a}{a^2\,+\,p^2}$
#
# Focusing on $p$ here, as noted above.
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.8 Find  the Laplace transform of $\hspace{0.5 cm}
# f(x)=
# \begin{cases}
# e^x \hspace{0.33 cm} x\,\le \,2 \\
# 3 \hspace{0,5 cm} x\,>\,2 \\
# \end{cases}
# $
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| find laplace transform of Piecewise[{{e^x, x <= 2}, {3, x >2}}] |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
#
# $ \large\frac{1}{p-1}\,-\,\frac{e^{-2p}\,(e^{2}p\,+\,3p\,+\,3)}{(p-1)\,p}$
#
# The above result differs in appearance somewhat from the text answer, so a plot here would be prudent. Several alternate forms of the result equation in Wolfram Alpha were available, and one in particular matches the text well.
#
# </font>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['svg']

x = np.linspace(-2,40,300)
y4 = (1 - np.exp(-2*(x - 1))   )/(x - 1) + (3 * np.exp(-2 * x))/x
y6 = 1/(x - 1) -(np.exp(-2 * x)*(np.exp(2)*x - 3 * x + 3)) / ((x - 1)*x)
                 
plt.grid(True, linestyle='dotted', color='gray', linewidth=0.9)
plt.xlabel("x")
plt.ylabel("y(x)")
plt.title("Outline of Differential Equations Prob 21.8")
plt.rcParams['figure.figsize'] = [9, 7.5]

        
ax = plt.gca()
ax.axhline(y=0, color='#993399', linewidth=0.7)
ax.axvline(x=0, color='#993399', linewidth=0.7)
ratio = 0.95
xleft, xright = ax.get_xlim()
ybottom, ytop = ax.get_ylim()
ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)


#plt.text(965, -2.5e43, "-np.log(abs((np.cos(x/2))**2 - (np.sin(x/2))**2)))
#plt.text(965, 2.25e43, "SOLN: y = 3*np.exp(x**2) + 1/2", size=10,\
        # bbox=dict(boxstyle="square", ec=('#8C564B'),fc=(1., 1., 1),))
plt.ylim(-20,20)
plt.plot(x, y4, linewidth = 4, color = '#7777CC')
plt.plot(x, y6, linewidth = 0.9, color = 'w')
plt.show()

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.9 Find the Laplace transform of the function graphed in Fig.21-1:$\hspace{0.5 cm}
# f(x)=
# \begin{cases}
# -1 \hspace{0.33 cm} x\,\le \,4 \\
# 1 \hspace{0,5 cm} x\,>\,4 \\
# \end{cases}
# $
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| find Laplace transform of Piecewise[{{-1, x <= 4}, {1, x >4}}] |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
#
# $ \large \frac{2e^{-4p}-1}{p}$
#
# The curvy plot of the above, contrasted with the step function appearance of the input function, reminds that things in Laplaceland look very different from the way they look in Regularland.
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.10 Find the Laplace transform of $\:\:f(x)\,=\,3\,+\,2x^2$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| find Laplace transform of f(x) = 3 + 2 * x^2 |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
#
# $ \large \frac{3p^2\,+\,4}{p^3}$
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.11 Find the Laplace transform of $\:\:f(x)\,=\,5\,\textrm{sin}\,3x\,-\,17e^{-2x}$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| find the Laplace transform of f(x) = 5 * sin(3 * x) - 17 * e^(-2 * x) |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
#
# $ \large \frac{15}{p^2\,+\,9}\,-\,\frac{17}{p\,+\,2}$
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.12 Find the Laplace transform of $\:\:f(x)\,=\,5\,\textrm{sin}\,3x\,-\,17e^{-2x}$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| find the Laplace transform of f(x) = 2 * sin( x) + 3 * cos(2 * x) |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
#
# $ \large \frac{3p}{p^2\,+\,4}\,+\,\frac{2}{p^2\,+\,1}$
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.13 Find the Laplace transform of $\:\:f(x)\,=\,5\,\textrm{sin}\,3x\,-\,17e^{-2x}$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| find the Laplace transform of f(x) = 2 * x^2 - 3x + 4  |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
#
# $ \large \frac{4p^2\,-\,3p\,+\,4}{p^3}\,$
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.14 Find $\mathscr{L}\,\{\,xe^{4x}\,\}$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| find the Laplace transform of x * e^(4 * x)  |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
#
# $ \large \frac{1}{(p \,-\,4)^2}\,$
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.15 Find $\mathscr{L}\,\{\,xe^{4x}\,\}$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# !| find the Laplace transform of  e^(-2 * x) * sin(5 * x) |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
#
# $ \large \frac{5}{(p\,+\,2)^2 \,+\,25}\,$
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.16 Find $\mathscr{L}\,\{\,x\,\textrm{cos}\,\sqrt{7}x\,\}$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The following entry **did not work** in Wolfram Alpha:<br>
#
# !| find the Laplace transform of x * cos(sqrt(7) * x) |!<br>
#
# A couple of small changes made it work:<br>
#
# !| laplace transform of x * cos(sqrt(7) * x) |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
#
# $ \large \frac{p^2\,-\,7}{(p^2\,+\,7)^2} \,$
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.17 Find $\mathscr{L}\,\{\,e^x\,x\,\textrm{cos}\,2x\,\}$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:
#
# !| laplace transform of e^x * x * cos(2 * x) |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
#
# $ \large \frac{p^2\,-\,2p\,-\,3}{(p^2\,-\,2p\,+\,5)^2} \,$
#
# The above answer does not match the answer in the text. However, with the answer above, performing an inverse Laplace transform recovers the problem expression, whereas, with the text answer, it does not. The text answer is:
#
# $ \large \frac{(s\,+\,1)^2 \,-\,4}{((s\,+\,1)^2\,+\,4)^2} \,$
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.18 Find $\mathscr{L}\,\{\,x^{7/2}\,\}$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:
#
# !| laplace transform of x^(7/2) |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
#
# $ \large \frac{105\,\sqrt{\pi}}{16 p^{9/2}} \,$
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.19 Find $ \mathscr{L}\,\large \{\frac{\textrm{sin}\,3x}{x}\,\}$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:
#
# !| laplace transform of sin(3 * x)/x |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
# $\large \frac{1}{2} \left(\small \pi - 2\,\textrm{tan}^{-1}\,\left(\large \frac{p}{3}\right)\right)$
#
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.20 Find $ \mathscr{L}\, \{\int_0^x\,\textrm{sinh}\,2t\,dt\,\}$.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:
#
# !| laplace transform of integrate[sinh(2 * t) dt] from 0 to x |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
#
# $\large \frac{2}{p\,(p^2\,-\,4)} $
#
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.22 Find  the Laplace transform of $\hspace{0.5 cm}
# f(x)=
# \begin{cases}
# 1 \hspace{0.85 cm} 0 < x\,\le \,1 \\
# -1 \hspace{0.5 cm} 1 < x\,\le \,2 \\
# \end{cases}
# $
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem is restated from the text to try to capture the function depicted there in a plot. However, apparently the attempt was not successful. The entry in Wolfram Alpha goes like:
#
# !| laplace transform of Piecewise[{{1, 0 < x <= 1}, {-1, 1 < x <=2}}] |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
#
# $\large \frac{e^{-2p}\,(e^p\,-1)^2}{p} $
#
# This result does not agree with that of the text, and neither does the general scale of the proceedings. A plot shows that the two functions are not the same in the frequency domain, so cannot be expected to coincide in the time domain either.
#
# As verification for the Wolfram Alpha solution, performing an inversve Laplace transform (in W|A) recovers the original time domain function, whereas when an inverse Laplace transform (also in W|A) is performed on the text solution, the notification is given: "no result found in terms of standard mathematical functions".
#
# As shown below, sympy does not choose to participate meaningfully.
#
#
#
#
#
# </font>
# </div>

# %%
from sympy import *

s = Symbol('s')
t = Symbol(' t', real=True, positive=True)

f = Piecewise( (1, t <= 1),
             (-1,  1 < t))
f
# Out:
# Piecewise((1,  t <= 1), (-1, True))

# %%
laplace_transform(f, t, s)
# Out:
# LaplaceTransform(Piecewise((1,  t <= 1), (-1, True)),  t, s)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['svg']

x = np.linspace(-2,2,300)
y4 = 1/x*np.tanh(x/2)
y6 = ((np.exp(-2*x))*(np.exp(x) - 1)**2)/x
                 
plt.grid(True, linestyle='dotted', color='gray', linewidth=0.9)
plt.xlabel("x")
plt.ylabel("y(x)")
plt.title("Outline of Differential Equations Prob 21.22")
plt.rcParams['figure.figsize'] = [4, 4]

        
ax = plt.gca()
ax.axhline(y=0, color='#993399', linewidth=0.7)
ax.axvline(x=0, color='#993399', linewidth=0.7)
ratio = 0.95
xleft, xright = ax.get_xlim()
ybottom, ytop = ax.get_ylim()
ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)


#plt.text(965, -2.5e43, "-np.log(abs((np.cos(x/2))**2 - (np.sin(x/2))**2)))
#plt.text(965, 2.25e43, "SOLN: y = 3*np.exp(x**2) + 1/2", size=10,\
        # bbox=dict(boxstyle="square", ec=('#8C564B'),fc=(1., 1., 1),))
plt.ylim(-2,2)
plt.plot(x, y4, linewidth = 0.9, color = '#7777CC')
plt.plot(x, y6, linewidth = 0.9, color = 'r')
plt.show()

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>21.24 Find  $\hspace{0.8 cm}\mathscr{L} \large\left\{\normalsize e^{4t}\,\small t\,\normalsize\int_0^\infty\,\frac{1}{t}\,e^{-4t}\, \small \textrm{sin}\,3t\,dt\right\} $
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The problem as set is something of a guess, due to botched typesetting in the text. As shown, the problem can be entered into Wolfram Alpha:
#
# !| laplace transform [e^(4 t) t int[(1/t) * e^(-4 t) * sin(3 t) dt, t=0..infinity ]]  |!<br>
#
# In Wolfram Alpha the result is expressed as:
#
# Result<br>
#
# $$ \frac{\textrm{tan}^{-1}\left(\frac{3}{4}\right)}{(s-4)^{\,2}} $$
#
# This result does not agree with that of the text, or have any identifiable resemblance.
#
#
# </font>
# </div>
