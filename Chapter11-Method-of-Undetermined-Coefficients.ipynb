# %% [markdown]
# <div style="background: #DDE2FF;
#             font-family: Bookerly;
#             font-size: 14px;
#             font-weight: 500;
#             padding: 30px 5px 30px 5px;
#             border: 30px solid #DDE2FF;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>(Custom CSS files are not reliable for controlling Jupyter font style. To establish the same appearance as the original notebook, depend on the browser to control the font, by setting the desired font faces in the browser settings. For example, Chrome 135 or Firefox 134 can do this. In this notebook series, Bookerly font is for markdown and Monaco is for code.)
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #DDE2FF;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 20px 5px 20px 5px;
#             border: 30px solid #DDE2FF;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>**Chapter 11: The Method of Undetermined Coefficients** <br><br>
#  This method is for use on nonhomogeneous equations. In general terms, it removes the rhs,
#  then initiates a search for constants after consulting the homogeneous version of the equation. When relying on Wolfram Alpha to do the heavy lifting, the method is basically skipped.
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>**Cutting and pasting and Wolfram Alpha.** Wolfram Alpha is amenable to accepting pasted entries. In this chapter pastable expressions are given a distinctive boundary fence, exemplified by the sample:  !| abcdef |!<br>
# $\hspace{2 em}$In the above pseudo-entry, only the alpha characters would be copied for transfer to Wolfram Alpha.
#
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 50px 5px 50px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>11.1 Solve $\,y\,''\,-\,y\,'\,-\,2y\,=\,4x^2\,$
#
#
#
#
# </font>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 40px 5px 40px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y'' - y' - 2 * y = 4 * x^2 |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_1\,e^{-x}\,+\,c_2\,e^{2x}\,-\,2x^2\,+\,2x\,-3\,$$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 50px 5px 50px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>11.2 Solve $\,y\,''\,-\,y\,'\,-\,2y\,=\,e^{3x}\,$
#
#
#
#
# </font>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y'' - y' - 2 * y = e^(3 * x) |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_1\,e^{-x}\,+\,c_2\,e^{2x}\,+\,\frac{e^{3x}}{4}\,$$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 40px 5px 40px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>11.3 Solve $\,y\,''\,-\,y\,'\,-\,2y\,=\,\textrm{sin}\,2x\,$
#
#
#
#
# </font>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y'' - y' -2 * y = sin(2 * x) |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_1\,e^{-x}\,+\,c_2\,e^{2x}\,-\,\frac{3}{20}\,\textrm{sin}\,(2x)\,+\,\frac{1}{20}\,\textrm{cos}\,(2x)\,$$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 40px 5px 40px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>11.4 Solve $\,\ddot{y}\,-\,6\,\dot{y}\,+\,25y\,=\,2\,\textrm{sin}\,\large\frac{t}{2}\small\,-\,\textrm{cos}\,\large\frac{t}{2}\,$
#
#
#
#
# </font>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| d^2y/dt^2 - 6 * dy/dt + 25 * y = 2 * sin(t/2) - cos(t/2) |!<br><br>
# and the answer is received:<br><br>
# $$\,y(t)\,=\,c_1\,e^{3t}\,\textrm{sin}\,(4t)\,+\,c_2\,e^{3t}\,\textrm{cos}\,(4t)\,+\,\frac{56}{663}\,\textrm{sin}\left(\frac{t}{2}\right)\,-\,\frac{20}{663}\,\textrm{cos}\,\left(\frac{t}{2}\right)\,$$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 40px 5px 40px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>11.5 Solve $\,\ddot{y}\,-\,6\,\dot{y}\,+\,25y\,=\,64e^{-t}\,$
#
#
#
#
# </font>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y'' - 6 * dy/dt + 25 * y = 64 * e^(-t) |!<br><br>
# and the answer is received:<br><br>
# $$\,y(t)\,=\,c_1\,e^{3t}\,\textrm{sin}\,(4t)\,+\,c_2\,e^{3t}\,\textrm{cos}\,(4t)\,+\,2e^{-t}\,$$<br>
#
# In this case Wolfram Alpha accepts the hint about the identity of the independent variable.
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 30px 5px 30px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>11.6 Solve $\,\ddot{y}\,-\,6\,\dot{y}\,+\,25y\,=\,50t^3\,-\,36t^2\,-\,63t\,+\,18\,$
#
#
#
#
# </font>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y'' - 6 * y' + 25 * y = 50 * t^3 - 36 * t^2 - 63 * t + 18 |!<br><br>
# and the answer is received:<br><br>
# $$\,y(t)\,=\,c_1\,e^{3t}\,\textrm{sin}\,(4t)\,+\,c_2\,e^{3t}\,\textrm{cos}\,(4t)\,+\,2e^{3}\,-\,3t\,$$<br>
#
# In this case Wolfram Alpha can identify independent and dependent variables by local review.
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 30px 5px 30px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>11.7 Solve $\,y\,'''\,-
# \,6y\,''\,+\,11y\,'\,-\,6y\,=\,2xe^{-x}\,$
#
#
#
#
# </font>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y''' - 6 * y'' + 11 * y' - 6 * y = 2 * x * e^-x |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_1\,e^x\,+\,c_2\,e^{2x}\,+\,c_3\,e^{3x}\,-\,\frac{1}{12}\,e^{-x}\,x\,-\,\frac{13e^{-x}}{144}\,$$<br>
#
# In this case Wolfram Alpha can identify independent and dependent variables by local review.
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 30px 5px 30px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>11.9 Solve $\,y\,''\,=\,9x^2\,+\,2x\,-\,1\,$
#
#
#
#
# </font>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y'' = 9 * x^2 + 2 * x - 1 |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_1\,x\,+\,c_2\,+\,\frac{3x^4}{4}\,+\,\frac{x^3}{3}\,-\,\frac{x^2}{2}\,$$<br>
#
# In this case Wolfram Alpha can identify independent and dependent variables by local review.
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 20px 5px 20px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>11.10 Solve $\,y\,'\,-\,5y\,=\,2e^{5x}\,$
#
#
#
#
# </font>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y' - 5 * y = 2e^(5 * x) |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_1e^{5x}\,+\,2e^{5x}\,x\,$$<br>
#
# In this case Wolfram Alpha can identify independent and dependent variables by local review.
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 20px 5px 20px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>11.12 Solve $\,y\,'\,-\,5y\,=\,(x\,-\,1)\,\textrm{sin}\,x\,+\,(x\,+\,1)\,\textrm{cos}\,x\,$
#
#
#
#
# </font>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y' - 5 * y = (x - 1) * sin(x) + (x + 1) * cos(x) |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_1e^{5x}\,-\,\frac{2}{13}\,x\,\textrm{sin}\,(x)\,+\,\frac{71\,\textrm{sin}\,(x)}{338}\,-\,\frac{3}{13}\,x\,\textrm{cos}\,(x)\,-\,\frac{69\,\textrm{cos}\,(x)}{338}\,$$<br>
#
# In this case Wolfram Alpha can identify independent and dependent variables by local review.
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 20px 5px 20px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>11.13 Solve $\,y\,'\,-\,5y\,=\,3e^x\,-\,2x\,+\,1\,$
#
#
#
#
# </font>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y' - 5 * y = 3 * e^x - 2 * x + 1 |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_1e^{5x}\,-\,\frac{2x}{5}\,-\,\frac{3\,e^x}{4}\,-\,\frac{3}{25}\,$$<br>
#
# In this case Wolfram Alpha can identify independent and dependent variables by local review.
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 20px 5px 20px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>11.14 Solve $\,y\,'\,-\,5y\,=\,x^2e^x\,-\,xe^{5x}\,$
#
#
#
#
# </font>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y' - 5 * y = x^2 * e^x - x * e^(5 * x) |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_1e^{5x}\,-\,\frac{1}{4}\,e^x\,x^2\,-\,\frac{1}{2}\,e^{5x}x^2\,-\,\frac{e^x\,x}{8}\,-\,\frac{e^x}{32}\,$$<br>
#
# In this case Wolfram Alpha can identify independent and dependent variables by local review.
#
#
#
# </font>
# </div>
