# %%
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# <div style="background: #DDE2FF;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 20px 5px 0px 5px;
#             border: 10px solid #DDE2FF;
#             margin-left: 1px;
#             margin-right: 1px;"
#
#  <font color='blue'>$\textbf{ Chapter 25: Solutions of Linear Systems by Laplace Transforms}$. Extending the convenience of Laplace transform solution to systems of two or more equations. When it comes to solving systems of ODEs, the Laplace method can sometimes allow successful solutions that would not otherwise be possible. In this problem set, Wolfram Alpha and Maxima team up to grind the grist, efficiently achieving a series of satisfactory outcomes.<br><br>
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>25.1 Solve the following system for the unknown functions $u(x)\,$ and $v(x)\,$:<br>
#
# $$u'\,+\,u\,-\,v\,=\,0\,$$
#
# $$v'\,-\,u\,+\,v\,=\,2;\,$$
#
# $$u(0)\,=\,1,\hspace{0.7 cm}v(0)\,=\,2$$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The first two equation lines above need to be taken independently into Laplaceland. Doing this with Wolfram Alpha will be deferred until Prob 25.3. For now, Maxima will do the honors.<br>
#
# Note: When transcribing text for entry into Wolfram Alpha the "fenceposts" !| ... |! are excluded from the text.
#
# Consider the interactive steps in the cell below: (Note: these Maxima lines are simply copied to this cell; no Maxima kernel is installed.)
#
# </font>
# </div>

# %%
(%i1) ode: 'diff(u(t), t) + u(t) - v(t) = 0;

                          d
(%o1)                     -- (u(t)) - v(t) + u(t) = 0
                          dt

(%i2) atvalue(u(t), t=0, 1);
(%o2)                                  1
(%i3) atvalue(v(t), t=0, 2);
(%o3)                                  2
(%i4) lap_ode: laplace(ode, t, s);

(%o4) (- laplace(v(t), t, s)) + s laplace(u(t), t, s) + laplace(u(t), t, s)
                                                                        - 1 = 0

(%i5) ode: 'diff(v(t), t) - u(t) + v(t) = 2;

                          d
(%o5)                     -- (v(t)) + v(t) - u(t) = 2
                          dt

(%i6) atvalue(u(t), t=0, 1);
(%o6)                                  1
(%i7) atvalue(v(t), t=0, 2);
(%o7)                                  2
(%i8) lap_ode: laplace(ode, t, s);

                                                                              2
(%o8) s laplace(v(t), t, s) + laplace(v(t), t, s) - laplace(u(t), t, s) - 2 = -
                                                                              s

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Output steps 5 and 10 express the relationships of the functions $U(s)$ and $V(s)$ in Laplacelandese. These correspond to:
#
# $$\,-V(s) \,+\,s \,U(s)\, +\,U(s)\,-\,1\,=\,0$$
#
# $$\,s\,V(s)\,+\,V(s)\,\,-\,U(s)\,-\,2\,=\, \frac{2}{s}\,$$
#
# with minor grooming
#
# $$-V\,+\,(s\,+\,1)\,U\,=\,1$$
#
# $$(s\,+\,1)\,V\,-\,U\,=\,\frac{2\,(1\,+\,s)}{s}$$
#
# The last two equations can be solved simultaneously by either Wolfram Alpha or sympy. W|A will be given the first try. The entry line is:
#
# !| solve[-v + (s + 1) u = 1, (s + 1) v - u = (2 (1 + s))/s], u, v |!
#
# and the results are:
#
# $$U(s)\,=\,\frac{s\,+\,1}{s^2}$$
#
# $$V(s)\,=\,\frac{2s\,+\,1}{s^2}$$
#
# Taking these back to Regularland. The first entry line is:
#
# !| inverse laplace transform[( s + 1)/s^2] |!, $\:\:\:$yielding $\hspace{1 cm}t\,+\,1$
#
# and the second entry line is:<br>
#
# !| inverse laplace transform[(2 s + 1)/s^2] |!, $\:\:\:$ yielding $\hspace{1 cm}t\,+\,2$
#
# meaning that the base functions are $f_1(x)\,=\, x\,+\,1\:$ and $f_2(x)\,=\,x\,+\,2\:$
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>25.2 Solve the system:<br>
#
# $$y\,'\,+\,z\,=\,x\,$$
#
# $$z'\,+\,4y\,=\,0;\,$$
#
# $$y(0)\,=\,1,\hspace{0.7 cm}z(0)\,=\,-1$$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The first two equation lines in the problem statement need to be taken independently into Laplaceland. Again, Maxima gets the assignment.<br>
#
# Consider the interactive steps in the cell below (concatenating 8 cells from the Maxima worksheet):
#
# </font>
# </div>

# %%
(%i1) ode: 'diff(y(t), t) + z(t) = t;

                             d
(%o1)                        -- (y(t)) + z(t) = t
                             dt

(%i2) atvalue(y(t), t=0, 1);
(%o2)                                  1
(%i3) atvalue(y(t), t=0, -1);
(%o3)                                 - 1
(%i4) lap_ode: laplace(ode, t, s);

                                                               1
(%o4)        laplace(z(t), t, s) + s laplace(y(t), t, s) + 1 = --
                                                                2
                                                               s

(%i5) ode: 'diff(z(t), t) + 4*y(t) = 0;

                            d
(%o5)                       -- (z(t)) + 4 y(t) = 0
                            dt

(%i6) atvalue(y(t), t=0, 1);
(%o6)                                  1
(%i7) atvalue(z(t), t=0, -1);
(%o7)                                 - 1
(%i8) lap_ode: laplace(ode, t, s);

(%o8)        s laplace(z(t), t, s) + 4 laplace(y(t), t, s) + 1 = 0

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>In the Maxima output, steps 21 and 25 express the relationships of the functions $Y(s)$ and $Z(s)$ in Laplacelandese. These correspond to:
#
# $$\,Z(s)\,+\,s\,Y(s)\,-1\,=\,\frac{1}{s^2}$$
#
# $$\,s\,Z(s)\,+\,4Y(s)\,+\,1\,=\,0\,$$
#
# with minor grooming
#
# $$Z(s)\,+\,s\,Y(s)\,=\,\frac{s^2\,+\,1}{s^2}$$
#
# $$\,s\,Z(s)\,+\,4Y(s)\,=\,-1\,$$
#
# The last two equations can be solved simultaneously by either Wolfram Alpha or sympy. W|A again gets the nod, being slightly more convenient. The entry line is:
#
# !| solve [z + s y = (s^2 + 1)/s^2, s z + 4 y = - 1], y, z |!
#
# and the results are:
#
# $$Y(s)\,=\,\frac{s^2\,+\,s\,+\,1}{s\,(s^2-4)}$$
#
# $$Z(s)\,=\,\frac{s^3\,+\,4s^2+\,4}{4s^2\,-s^4}$$
#
# (For a moment it looks like the solution herein will differ from that of the text. The inconsistency is solved, however. Still, there is a cell from sympy checking the simultaneous equation calculation, and that is included below.)
#
# Taking the solutions back to Regularland. The first entry line is:
#
# !| inverse laplace transform[(s^2 + s + 1)/(s (s^2 - 4))] |!, $\:\:\:$yielding $\hspace{1 cm}\large \frac{3\,e^{-2t}}{8}\,\small +\,\large\frac{7\,e^{2t}}{8}\,\small-\,\large \frac{1}{4}$
#
# and the second entry line is:<br>
#
# !| inverse laplace transform[(s^3 + 4 s^2 + 4)/(4 s^2 - s^4)] |!, $\:\:\:$ yielding $\hspace{1 cm}t\,+\,\large \frac{3e^{-2t}}{4}\,\small -\,\large \frac{7\,e^{2t}}{4}$\,
#
# meaning that the base functions will follow the last templates with $x$ substituting for $t$.
#
#
#
#
#
#
#
# </font>
# </div>

# %%
from sympy import *

y, z, s = symbols('y, z, s')
eq1 = Eq(z + s*y, (s**2 + 1)/s**2)
eq2 = Eq(s*z + 4*y, -1)
res = solve([eq1, eq2], (y, z))
print(res)
# Out:
# {y: (s**2 + s + 1)/(s**3 - 4*s), z: (-s**3 - 4*s**2 - 4)/(s**4 - 4*s**2)}

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>25.3 Solve the system:<br>
#
# $$w\,'\,+\,y\,=\,\textrm{sin}\,x\,$$
#
# $$y'\,-\,z\,=\,e^x;\,$$
#
# $$z'\,+\,w\,+\,y\,=\,1;\,$$
#
# $$w(0)\,=\,0,\hspace{0.5 cm}y(0)\,=\,1 \hspace{0.5 cm}z(0)\,=\,1$$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The first three equation lines in the problem statement need to be taken independently into Laplaceland. This time Wolfram Alpha will be the engine. The format that will be tried for the first step is:
#
# ① !| laplace transform[w'(t) + y(t) = sin(t), t, s, {w(0) = 0, y(0) = 1}] |!
#
# With only $w$ and $y$ involved in this step, there is no need to enter the initial value for $z$. The result of the above command is:
#
# $$s\,W(s)\,+\,Y(s)\,=\,\frac{1}{s^2\,+\,1}\,+\,w(0)$$
#
# The entry that will be tried for the second step is:
#
# ② !| laplace transform[y'(t) - z(t) = e^t, t, s, {y(0) = 1, z(0) = 1}] |!
#
# With only $y$ and $z$ involved in this step, there is no need to enter the initial value for $w$. The result of the above command is:
#
# $$s \, Y(s)\,-\,Z(s) \,=\,\frac{1}{s\,-\,1}\,+\,y(0)$$
#
# The entry that will be tried for the third step is:
#
# ③ !| laplace transform[z'(t) + w(t) + y(t) = 1, t, s, {w(0) = 0, y(0) = 1, z(0) = 1}] |!
#
# Since all three variables are involved in this step, it is necessary to include all three initial conditions. The result of the above command is:
#
# $$W(s) \, +\,Y(s)\,+\,s \,Z(s)\,=\,\frac{1}{s}\,+\,z(0)$$
#
# There is no reformulation necessary on the three equations before simultaneous solution. Therefore, inserting the initial conditions as they make appearance, the simultaneous command in Wolfram Alpha looks like:
#
# !| solve[s w + y = 1/(s^2 + 1), s y - z = 1/(s - 1) +1, w + y + s z =1/s + 1], w, y, z |!
#
# and the result is:
#
# $$W(s) \,=\,-\frac{1}{(s\,-\,1)\,s}$$
#
# $$Y(s)\,=\,\frac{s^2\,+\,s}{(s\,-\,1)\,(s^2\,+\,1)}$$
#
# $$Z(s)\,=\,\frac{s}{s^2\,+\,1}$$
#
# Time now to take these expressions back to Regularland. The first entry in Wolfram Alpha is:
#
# ① !| inverse laplace transform[-1/(s (s  - 1)), s, t] |!
#
# and the result is:$$1\,-\,e^t$$
#
# The second entry in Wolfram Alpha is:
#
# ② !| inverse laplace transform[(s^2 + s)/( (s  - 1) (s^2 + 1)), s, t] |!
#
# and the result is:
#
# $$e^t\,+\,\textrm{sin}\,(t)$$
#
# The third entry in Wolfram is:
#
# ③ !| inverse laplace transform[s/(s^2 + 1), s, t] |!
#
# and the result is:
#
# $$\textrm{cos}\,(t)$$
#
# In Regularland the $t$ symbols are replaced with $x$, which concludes the answer.
#
#
#
#
#
#
#
#
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>25.4 Solve the system:<br>
#
# $$y\,''\,+\,z\,+\,y\,=\,0\,$$
#
# $$z'\,+\,y\,'\,=\,0;\,$$
#
# $$y(0)\,=\,0,\hspace{0.7 cm}y\,'(0)\,=\,0\hspace{0.7 cm}z(0)\,=\,1$$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The first two equation lines in the problem statement need to be taken independently into Laplaceland. This time Wolfram Alpha will be the engine. The format that will be tried for the first step is:
#
# ① !| laplace transform[y''(t) + z(t) +y(t) = 0, t, s, {y(0) = 0, y'(0) = 0, z(0) =1}] |!
#
# Both $y$ and $z$ are involved in this step, so all three initial conditions need to be included. The result of the above command is:
#
# $$(s^2\,+\,1)\,Y(s)\,+\,Z(s)\,=\,s \,y(0)\,+\,y'(0)$$
#
# The entry that will be tried for the second step is:
#
# ② !| LaplaceTransform[ z'(t) + y'(t) = 0, t, s, {y(0) = 0, y'(0) = 0, z(0) = 1}] |!
#
# The second step fails, Wolfram Alpha will not accept it, because both $z(t)$ and $y(t)$ are expressed as differentials. There may be a special method to avoid this difficulty, but a little experimentation does not reveal it. Switching horses in midstream, the second step will be transferred to Maxima.
#
# Picking up with Maxima, the interaction necessary to take the second problem description line to Laplaceland is shown below, culminating with output line 17.
#
#
#
# </font>
# </div>

# %%
(%i1) ode: 'diff(z(t), t) + 'diff(y(t), t) = 0;

                           d           d
(%o1)                      -- (z(t)) + -- (y(t)) = 0
                           dt          dt

(%i2) atvalue(y(t), t=0, 0);
(%o2)                                  0
(%i3) atvalue('diff(y(t), t), t=0, 0);
(%o3)                                  0
(%i4) atvalue(z(t), t=0, 1);
(%o4)                                  1
(%i5) lap_ode: laplace(ode, t, s);

(%o5)        s laplace(z(t), t, s) + s laplace(y(t), t, s) - 1 = 0

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Translating the Maxima output:
#
# $$s \, Z(s)\,+\,s \,Y(s)\,-\,1\,=\,0\,$$
#
# So the two equations to be solved simultaneously will be the first from Wolfram Alpha and the second from Maxima, and the input line in W|A will be:
#
# !| solve[(s^2 + 1) y + z = 0, s z + s y - 1 = 0], y, z |!
#
# and the result is:
#
# $$Y(s)\,=\,-\frac{1}{s^3}$$
#
# $$Z(s) \,=\,\frac{1}{s^3}\,+\,\frac{1}{s}$$
#
#
#
# Time now to take these expressions back to Regularland. The first entry in Wolfram Alpha is:
#
# ① !| inverse laplace transform[-1/s^3, s, t] |!
#
# and the result is:$$-\frac{t^2}{2}$$
#
# The second entry in Wolfram Alpha is:
#
# ② !| inverse laplace transform[1/s^3 + 1/s, s, t] |!
#
# and the result is:
#
# $$\,\frac{t^2}{2}\,+\,1$$
#
# In Regularland the $t$ symbols are replaced with $x$, which concludes the answer.
#
#
#
#
#
#
#
#
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>25.5 Solve the system:<br>
#
# $$z\,''\,+\,y\,'\,=\,\textrm{cos}\,x\,$$
#
# $$y\,''\,-\,z\,=\,\textrm{sin}\,x;\,$$
#
# $$z(0)\,=\,-1,\hspace{0.7 cm}z'\,(0)\,=\,-1\hspace{0.7 cm}y(0)\,=\,1\,\hspace{0.7 cm}y\,'(0)\,=\,0$$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The role of Maxima.
#
# Wolfram Alpha will not accept this system of equations, there seems to be a superfluity of differential signs. So Maxima will have to pick up the slack. Both the first and second lines of the problem description are generated by Maxima, as shown on output lines 41 and 47 of the following two cells.The smoothed expression of these Laplaceland equations are shown below.
#
# $$s^2\,Z(s)\,+\,s \,Y(s)\,+\,s\,=\,\frac{s}{s^2\,+\,1}\,$$
#
# $$-\,Z(s)\,+\,s^2\,Y(s)\,-\,s\,=\,\frac{1}{s^2\,+\,1}$$
#
#
# The two equations above could be simplified slightly, but regardless, there will be a lot of $s$ symbols lying around afterwards, and since they are only intermediate results, it is just as well to leave everything as it is for the simultaneous equation:
#
# !| solve[s^2 z + s y + s = s/(s^2 + 1), -z + s^2 y - s = 1/(s^2 + 1)], y, z |!
#
# and the result is:
#
# $$y\,=\,\frac{s}{s^2\,+\,1}$$
#
# $$z\,=\,-\frac{s\,+\,1}{s^2\,+\,1}$$
#
# The equations above are staged and ready to be transformed back to Regularland. The first is inversely transformed with the line:
#
#  !| inverse laplace transform[s/(s^2 + 1), s, t] |!
#
# and the result is:
#
# $$\textrm{cos}\,(t)$$
#
# The second is inversely transformed with the line:
#
# !| inverse laplace transform[-(s + 1)/(s^2 + 1), s, t] |!
#
# and the result is:
#
# $$-\textrm{sin}\,(t) \,-\,\textrm{cos}\,(t)$$
#
# In Regularland the $t$ symbols are replaced with $x$, which concludes the answer.
#
#
# </font>
# </div>

# %%
(%i1) ode: 'diff(z(t), t, 2) + 'diff(y(t), t) = cos(t);

                         2
                        d            d
(%o1)                   --- (z(t)) + -- (y(t)) = cos(t)
                          2          dt
                        dt

(%i2) atvalue(z(t), t=0, -1);
(%o2)                                 - 1
(%i3) atvalue('diff(z(t), t), t=0, -1);
(%o3)                                 - 1
(%i4) atvalue(y(t), t=0, 1);
(%o4)                                  1

(%i5) atvalue('diff(y(t), t), t=0, 0);
(%o5)                                  0
(%i6) lap_ode: laplace(ode, t, s);

           2                                                     s
(%o6)     s  laplace(z(t), t, s) + s laplace(y(t), t, s) + s = ------
                                                                2
                                                               s  + 1

(%i7) ode2: 'diff(y(t), t, 2) - z(t) = sin(t);

                           2
                          d
(%o7)                     --- (y(t)) - z(t) = sin(t)
                            2
                          dt

(%i8) atvalue(z(t), t=0, -1);
(%o8)                                 - 1
(%i9) atvalue('diff(z(t), t), t=0, -1);
(%o9)                                 - 1
(%i10) atvalue(y(t), t=0, 1);
(%o10)                                 1
(%i11) atvalue('diff(y(t), t), t=0, 0);
(%o11)                                 0
(%i12) lap_ode2: laplace(ode2, t, s);

                                    2                             1
(%o12)   (- laplace(z(t), t, s)) + s  laplace(y(t), t, s) - s = ------
                                                                 2
                                                                s  + 1

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>25.6 Solve the system:<br>
#
# $$w''\,-\,y\,+\,2z\,=\,3\,e^{-x}\,$$
#
# $$\,-2w'\,+\,2y\,'\,+\,z\,=\,0\,$$
#
# $$\,2w'\,-\,2y\,+\,z'\,+\,2z''\,=\,0;\,$$
#
# $$w(0)\,=\,1,\hspace{0.7 cm}w'\,(0)\,=\,1,\hspace{0.7 cm}y(0)\,=\,2,\,\hspace{0.7 cm}z(0)\,=\,2,\hspace{0.7 cm}z'(0)\,=\,-2\,$$
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>There is no sense in even considering Wolfram Alpha to work on this system; the number of prime symbols in the second and third equations would overwhelm it. So it will have to be Maxima again. The Laplaceland equivalent equations are described on output lines 27, 40, and 47 of the following three cells. In Laplacelandese, they are:
#
# $$2\,Z(s)\,-\,Y(s)\,+ \,s^2\,W(s)\,-\,s\,-\,1\,=\,\frac{3}{s\,+\,\textrm{log}\,(e)}$$
#
# $$Z(s)\,+\,2\,(s\,Y(s)\,-\,2\,)\,-\,2\,(s^2\,W(s)\,-\,s\,-\,1)\,=\,0$$
#
# $$2\,(s^2\,Z(s)\,-\,2s\,+\,2)\,+\,s\,Z(s)\,-\,2\,Y(s)\,+\,2\,(s\,W(s)\,-\,1)\,-\,2\,=\,0$$
#
# There is no disputing the fact that the above three equations could benefit from some collecting and simplifying. However, since the simultaneous equations will be solved just as quickly in a slightly disorganized syntax, nothing about appearance will be done at this time.
#
# The entry that will be tried for the simultaneous equation calculation is:
#
# !| solve[2 z -y + s^2 w - s-1 = 3/(s + 1), z + 2 (s y - 2)- 2 (s^2 w -s -1) = 0, 2 (s^2 z - 2 s + 2) + s z - 2 y + 2 (s w - 1) - 2=0],w, y, z |!
#
# Not only was Wolfram Alpha able to process this complex system of simultaneous equations, it provided 5 different forms of solution sets. The most intuitive one of these was checked against the text solution. It is:
#
# $$w\,=\,\frac{1}{s\,-\,1}$$
#
# $$y\,=\,\frac{2s}{s^2\,-\,1}$$
#
# $$z\,=\,\frac{2}{s\,+\,1}$$
#
# The problem is almost but not quite finished. The equations above have to be inverse transformed back to Regularland. The first entry line is:
#
# !| inverse laplace transform[1/(s -1), s, t] |!
#
# and the solution is: $\hspace{1 em}e^t\hspace{1 em}$. The second entry line is:
#
# !| inverse laplace transform[(2 s)/(s^2 -1), s, t] |!
#
# and the solution is: $\hspace{1 em}e^{-t}(e^{2t}\,+\,1)\hspace{1 em}$. The third entry line is:
#
# !| inverse laplace transform[2/(s + 1), s, t] |!
#
# and the solution is: $\hspace{1 em}2\,e^{-t}$
#
# In Regularland the $t$ symbols are replaced with $x$, which concludes the answer.
#
#
#
#
#
#
# </font>
# </div>

# %%
(%i1) ode: 'diff(w(t), t, 2) - y(t) + 2*z(t) = 3*e^(-t);

                         2
                        d                            3
(%o1)                   --- (w(t)) + 2 z(t) - y(t) = --
                          2                           t
                        dt                           e

(%i2) atvalue(w(t), t=0, 1);
(%o2)                                  1
(%i3) atvalue('diff(w(t), t), t=0, 1);
(%o3)                                  1
(%i4) atvalue(y(t), t=0, 2);
(%o4)                                  2
(%i5) atvalue(z(t), t=0, 2);
(%o5)                                  2
(%i6) atvalue('diff(z(t), t), t=0, -2);
(%o6)                                 - 2
(%i7) lap_ode: laplace(ode, t, s);

                                                     2
(%o7) 2 laplace(z(t), t, s) - laplace(y(t), t, s) + s  laplace(w(t), t, s) - s

                                                                         3
                                                               - 1 = ----------
                                                                     s + log(e)

(%i8) ode2: -2*'diff(w(t), t, 2) + 2*'diff(y(t), t) + z(t) = 0;

                                       2
                      d               d
(%o8)              2 (-- (y(t))) - 2 (--- (w(t))) + z(t) = 0
                      dt                2
                                      dt

(%i9) atvalue(w(t), t=0, 1);
(%o9)                                  1
(%i10) atvalue('diff(w(t), t), t=0, 1);
(%o10)                                 1
(%i11) atvalue(y(t), t=0, 2);
(%o11)                                 2
(%i12) atvalue(z(t), t=0, 2);
(%o12)                                 2
(%i13) atvalue('diff(z(t), t), t=0, -2);
(%o13)                                - 2
(%i14) lap_ode2: laplace(ode2, t, s);

(%o14) laplace(z(t), t, s) + 2 (s laplace(y(t), t, s) - 2)

                                             2
                                       - 2 (s  laplace(w(t), t, s) - s - 1) = 0

(%i15) ode3: 2*'diff(w(t), t) - 2*y(t) + 'diff(z(t), t) + 2*'diff(z(t), t, 2) = 0;

                2
               d             d              d
(%o15)      2 (--- (z(t))) + -- (z(t)) + 2 (-- (w(t))) - 2 y(t) = 0
                 2           dt             dt
               dt

(%i16) atvalue(w(t), t=0, 1);
(%o16)                                 1
(%i17) atvalue('diff(w(t), t), t=0, 1);
(%o17)                                 1
(%i18) atvalue(y(t), t=0, 2);
(%o18)                                 2
(%i19) atvalue(z(t), t=0, 2);
(%o19)                                 2
(%i20) atvalue('diff(z(t), t), t=0, -2);
(%o20)                                - 2
(%i21) lap_ode3: laplace(ode3, t, s);

           2
(%o21) 2 (s  laplace(z(t), t, s) - 2 s + 2) + s laplace(z(t), t, s)
                - 2 laplace(y(t), t, s) + 2 (s laplace(w(t), t, s) - 1) - 2 = 0
