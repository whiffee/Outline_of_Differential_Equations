# %%
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# <div style="background: #DDE2FF;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 20px 5px 0px 5px;
#             border: 10px solid #DDE2FF;
#             margin-left: 1px;
#             margin-right: 1px;"
#
#  <font color='blue'>$\textbf{ Chapter 24: Solutions of Linear Differential Equations with Constant Coefficients by Laplace Transforms}$. Introduction to a far reaching system for simplification of the ODE solving process. The transform is from the time domain to the frequency domain, where algebraic operations are performed before inverse transportation back to the time domain. The main variable governing the frequency domain is $s$, and the time domain $t$.
#
# When a Laplace transform is performed, it should be accomplished cleanly, with no leftover $x$ or $y$ factors. The presence of any such is an ill omen, because it can involve complexities. Like hunting through the transform table trying to make things come out right. In this notebook the first attempt will be without Laplace.
#
# Whereas functions got Laplace-transformed or Laplace-inverse-transformed in previous chapters, this chapter, for the first time, includes ODEs which see transformations in both directions within the same problem. This set of 'complete' cases includes Problems 24.7a, 24.8, 24.9, and 24.10.
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.1 Solve $y\,'\,-\,5y\,=\,0; \hspace{0.5 cm}y(0)\,=\,2$.<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
# ➀ $\hspace{0.5 cm}$ !| y' - 5 y = 0, y(0) = 2 |!<br>
#
# In Wolfram Alpha the expression is referred to as the "Differential equation solution":
#
#
# $2e^{5x}$
#
#
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.2 Solve $y\,'\,-\,5y\,=\,e^{5x}; \hspace{0.5 cm}y(0)\,=\,0$.<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
#  !| y' - 5 y = e^(5 * x), y(0) = 0 |!<br>
#
# In Wolfram Alpha the expression is referred to as the "Differential equation solution":
#
#
# $y(x)\,=\,e^{5x}\,x$
#
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.3 Solve $y\,'\,+\,y\,=\,\textrm{sin}\,x; \hspace{0.5 cm}y(0)\,=\,1$.<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
#  !| y' + y = sin(x), y(0) = 1 |!<br>
#
# In Wolfram Alpha the expression is referred to as the "Differential equation solution":
#
#
# $y(x)\,=\,\large \frac{1}{2}\small (3\,e^{-x}\,+\,\textrm{sin}(x)\,-\,\textrm{cos}(x))$
#
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.4 Solve $y\,''\,+\,4y\,=\,0; \hspace{0.5 cm}y(0)\,=\,2, \,y'(0)\,=\,2$.<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
#  !| y'' + 4 y = 0, y(0) = 2, y'(0) = 2 |!<br>
#
# In Wolfram Alpha the expression is referred to as the "Differential equation solution":
#
#
# $y(x)\,=\,\textrm{sin}(2x)\,+\,2\,\textrm{cos}(2x))$
#
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.5 Solve $y\,''\,-\,3y\,'\,+\,4y\,=\,0; \hspace{0.5 cm}y(0)\,=\,1, \,y\,'(0)\,=\,5$.<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
#  !| y'' - 3 y' + 4 y = 0, y(0) = 1, y'(0) = 5 |!<br>
#
# In Wolfram Alpha the expression is referred to as the "Differential equation solution":
#
#
# $y(x)\,=\,\normalsize e^{3x/2}\left(\sqrt{7} \,\textrm{sin}\,\left(\large \frac{ \sqrt{7}x}{2} \small \right) \,+\,\textrm{cos}\,\left( \large \frac{\sqrt{7}x}{2}\right)\right)\,$

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.6 Solve $y\,''\,-\,y\,'\,-\,2y\,=\,4x^2; \hspace{0.5 cm}y(0)\,=\,1, \,y\,'(0)\,=\,4$.<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
#  !| y'' -  y' - 2 y = 4 x^2, y(0) = 1, y'(0) = 4 |!<br>
#
# In Wolfram Alpha the expression is referred to as the "Differential equation solution":
#
#
# $y(x)\,=\,-2x^2 \,+\,2x\,+\,2e^{-x}\,+\,2e^{2x}\,-\,3\,$

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.7 Solve $y\,''\,+\,4y\,'\,+\,8y\,=\,\textrm{sin}\,x; \hspace{0.5 cm}y(0)\,=\,1, \,y\,'(0)\,=\,0$.<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
#  !| y'' + 4 y' +  8 y = sin(x), y(0) = 1, y'(0) = 0 |!<br>
#
# In Wolfram Alpha the expression is referred to as the "Differential equation solution":
#
#
# $y(x)\,=\,\large \frac{1}{65}\,\small e^{-2x}\,(7e^{2x}\,\textrm{sin}\,(x)\,+
# \,69\,\textrm{cos}\,(2x)\,+\,(131\,\textrm{sin}\,(x)\,-\,4e^{2x})\,\textrm{cos}\,(x))\,$
#
# The form assumed by the text answer versus the above W|A answer were somewhat tricky to reconcile, so a plot appears below, demonstrating their equality.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['svg']

#x = np.arange(0, 3., 0.005)
x = np.linspace(-10,10,300)
y3 = (1/65)*np.exp(-2*x)*(7*np.exp(2*x)*np.sin(x) + 69*np.cos(2*x) + (131*np.sin(x) - 4*np.exp(2*x))*np.cos(x))
y4 = (np.exp(-2*x))*((69/65)*np.cos(2*x) + (131/130)*np.sin(2*x)) + (7/65)*np.sin(x) - (4/65)*np.cos(x)

        
plt.grid(True, linestyle='dotted', color='gray', linewidth=0.9)
plt.xlabel("x")
plt.ylabel("y(x)")
plt.title("Outline of Differential Equations Prob 24.7")
plt.rcParams['figure.figsize'] = [9, 7.5]

        
ax = plt.gca()
#ax.axhline(y=0, color='#993399', linewidth=0.8)
ax.axvline(x=0, color='#993399', linewidth=0.8)
ratio = 0.95
xleft, xright = ax.get_xlim()
ybottom, ytop = ax.get_ylim()
ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)


#plt.text(965, -2.5e43, "-np.log(abs((np.cos(x/2))**2 - (np.sin(x/2))**2)))
#plt.text(965, 2.25e43, "SOLN: y = 3*np.exp(x**2) + 1/2", size=10,\
        # bbox=dict(boxstyle="square", ec=('#8C564B'),fc=(1., 1., 1),))
plt.ylim(-28,1.5)
plt.plot(x, y3, linewidth = 3)
plt.plot(x, y4, linewidth = 0.9, color = 'w')
plt.show()

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.7a
#
# Solve the IVP
#
# $$y''\,+\,3y'\,+\,2y\,=\,f(t),\hspace{1 cm} y(0)\,=\,2,\: y'(0)\,=\,3$$
#
# when the right-hand function equals
#
# $$f(t)\,=\,\begin{cases}
# 1 &\hspace{.5 cm} t<3\\
# t-2 & \hspace{.5 cm}3<t<6\\
# 2 & \hspace{.5 cm}t>6
# \end{cases}
# $$
#
#
# Note: this problem (performed in Matlab) can be seen at the following address: https://www.math.umd.edu/~petersd/246h/matlablaplace.html
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>To understand how the author puts the piecewise form into a general equation takes a little bit of Heaviside step function knowledge. To write the rhs in a general form would look like the following:
#
# $$f(t)\,=\,f_1(t)\,+\,(f_2(t)\,-\,f_1(t))\theta (t-t_1)\,+\,(f_3(t)\,-\,f_2(t))\theta (t-t_2)$$
#
# where the subscripts on $f$ correspond to the piecewise function pieces, numbered from top to bottom, and the symbol $\theta$ represents the Heaviside function.
#
# Most of the calculation for the problem can be done by Maxima (replacing the original Matlab procedure.) The wxMaxima worksheet section follows the procedure on the tutorial page exactly, (except that in the tutorial there is no need to insert a rhs piecewise $f(t)$):  https://maxima.sourceforge.io/docs/tutorial/en/gaertner-tutorial-revision/Pages/ODE0002.htm
#
#
# </font>
# </div>

# %% [markdown]
# ![chap24fig1a.svg](attachment:chap24fig1a.svg)

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The following cell shows the Maxima solution to the ODE. The only place Maxima fails is in grappling with the 'map' command line and thus failing to elucidate the Regularland (time series) solution. Maxima inserts a little yellow blob to admit its failure. But the omission can be made up by Wolfram Alpha, with the transcribed 'map' line's determined quantity:
#
# !| inverse laplace transform \[e^(-6 s) ((2 s^3+9 s^2+s) e^(6 s)+e^(3 s)-2s-1)/(s^4+3 s^3+2 s^2),s,t \] |!
#
# Wolfram's output is $g(t)$. The resulting plot matches the original site's plot perfectly.
#
# (Maxima trivia note. A good deal of web and doc searching will not reveal the way to voluntarily insert a line break into an input cell. A little experimentation shows that it's merely necessary to enter a keyboard return to effect the desired line-split, which affects visual appearance but not functionality.)
# </font>
# </div>

# %% [markdown]
# ![chap24fig2b180.svg](attachment:chap24fig2b180.svg)

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.8 Solve $y\,''\,-\,2y\,'\,+\,y\,=\,f(x); \hspace{0.5 cm}y(0)\,=\,0, \,y\,'(0)\,=\,0$.<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem cannot be entered into Wolfram Alpha. W|A rejects it in both interpretations: as a differential equation for solving, or as an input to a Laplace transform conversion.<br>
#
# The problem seems a little odd, but the intent is apparently to show how to deal with an unspecified rhs.
#
# Proceeding in this direction, the following Maxima worksheet is produced.

# %% [markdown]
# ![prob29.8fig1c.svg](attachment:prob29.8fig1c.svg)

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Above: Maxima gets confused about how to handle the inverse transform of a dummy function. Looking at the 'map' line, the inverse transform of the transform of a dummy function logically needs to recover the function. So the numerator of the floundering fraction can be nabbed for later re-insertion.

# %% [markdown]
# ![prob29.8fig2.svg](attachment:prob29.8fig2.svg)

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Above: The 'map' line as written previously proceeds without its numerator, then the numerator is appled artificially, as described. The form matches the text answer.

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.9 Solve $y\,''\,+\,y\,=\,f(x); \hspace{0.5 cm}y(0)\,=\,0, \,y\,'\,(0)\,=\,0\,\:
# \textrm{if} \hspace{1 em}
# f(x) =
# \begin{cases}
# 0 \hspace{1 cm} x\,\ < \,1 \\
# 2 \hspace{1 cm} x\,\ge\, 1 \\
# \end{cases}
# $.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem is similar to 24.7a above. The Heaviside configuration is simpler on this one than the former.

# %% [markdown]
# ![prob24.9fig1w.svg](attachment:prob24.9fig1w.svg)

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The problem is pretty simple except for the hstep function. Apparently this increases the difficulty to the point that Maxima is unable to calculate the inverse transform of the solution. So as in Problem 24.7a, Wolfram Alpha must be called on, with the input line:
#
# !| inverse laplace transform[2 e^(-s)/(s^3+s),s,t] |!

# %% [markdown]
# ![prob24.9fig2.svg](attachment:prob24.9fig2.svg)

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The output from Wolfram Alpha is the function $g(t)$.  However, the text expresses the answer as in the function $h(t)$. These two functions are plotted on top of each other by Gnuplot, and so it is assumed that they are equivalent.

# %% [markdown]
# ![prob24.9fig3.svg](attachment:prob24.9fig3.svg)

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.10 Solve $y\,'''\,+\,y\,'\,=\,e^x; \hspace{0.5 cm}y(0)\,=y\,'(0)\,=\,y\,''(0)\,=\,0$.<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Now the Heaviside regimen appears to be over. However, Maxima will still take the starting role.

# %% [markdown]
# ![prob24.10fig1.svg](attachment:prob24.10fig1.svg)

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>It appears that third order is beyond Maxima's capabilities. With the transform of the target function available, Wolfram Alpha can take it from here.
#
# !| solve[s^3 y + s y = 1/(s -1)], y |!
#
# gives the solution to $Y(s)$ in s-space, which is
#
# $\,y\,=\,\large \frac{1}{s\,(s^3\,-\,s^2\,+\,s\,-\,1)}$
#
#
#
# Then
#
# !| inverselaplacetransform[1/(s (s^3 - s^2 + s - 1)) |!
#
# takes the solution back to t-space, resulting in
#
# $\large \frac{1}{2} \small (e^t\,-\,\textrm{sin}\,(t)\,+\,\textrm{cos}\,(t)\,-2\,)$
#
# or, un-substituting,
#
# $\large \frac{1}{2} \small (e^x\,-\,\textrm{sin}\,(x)\,+\,\textrm{cos}\,(x)\,-2\,)$

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.11 Solve $y\,'\,-\,5y\,=\,0$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
#  !| y' - 5 y = 0 |!<br>
#
# In Wolfram Alpha the expression is referred to as the "Differential equation solution":
#
#
# $y(x)\,=\,c_1\,e^{5x}\,$
#
# Without an initial condition, an arbitrary constant attaches.

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.12 Solve $y\,''\,-\,3y\,'\,+\,2y\,=\,e^{-x}$<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
#  !| y'' - 3 y' + 2 y = e^(-x) |!<br>
#
# In Wolfram Alpha the expression is referred to as the "Differential equation solution":
#
#
# $y(x)\,=\,c_1\,e^x\,+\,c_2\,e^{2x}\,+\,\large \frac{e^{-x}}{6}\,$
#
# Without an initial conditions, arbitrary constants for each level of order attach.

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.13 Solve $y\,''\,-\,3y\,'\,+\,2y\,=\,e^{-x}; \hspace{0.5 cm}\small y(1)\,=\,0, \,y\,'(1)\,=\,0$.<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem can be entered into Wolfram Alpha:<br>
#
#  !| {y'' - 3 y' + 2 y = e^(-x), {y(1) = 0, y'(1) = 0 }} |!<br>
#
# In Wolfram Alpha the expression is referred to as the "Differential equation solution":
#
#
# $y(x)\,=\,\large \frac{1}{6} \small \,e^{-x-3}\,(e\,-\,e^x)^2\,(2e^x\,+\,e)\,$

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.14 Solve $\large \frac{dN}{dt}\,\small =\,0.05N; \hspace{0.5 cm}\small N(0)\,=\,20000\,$.<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Wolfram Alpha seems inclined to refuse this problem, but with the right technique it can be run. The form of the entry, even the specific symbols, matter.<br>
#
#  !| {y' = 0.05 y}, { y(0) = 20000} |!<br>
#
# In Wolfram Alpha the expression is referred to as the "Differential equation solution":
#
#
# $y(x)\,=\,20000\,e^{0.05x}\,$
#
# that is,
#
# $N(t)\,=\,20000\,e^{0.05t}\,$

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.15 Solve $\large \frac{dI}{dt}\,\small\,+\, 50I =\,5; \hspace{0.5 cm}\small I(0)\,=\,0\,$.<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>Wolfram Alpha might be inclined to refuse this problem, but with the technique shown in Prob 24.14 it can be run. The form of the entry, even the specific symbols, matter.<br>
#
#  !| {y' + 50 y = 5}, {y(0) = 0} |!<br>
#
# In Wolfram Alpha the expression is referred to as the "Differential equation solution":
#
#
# $y(x)\,=\,\normalsize \frac{1}{10}\,\small (1\,-\,e^{-50\,x})\,$
#
# that is,
#
# $I(t)\,=\,\normalsize \frac{1}{10}\,\small (1\,-\,e^{-50\,t})\,$

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 15px 5px 10px 5px;
#             border: 10px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>24.16 Solve $\,\ddot{x}\,+\,16x\,=\,2\,\textrm{sin}\,4t; \hspace{0.5 cm}\small x(0)\,=\,-\,\frac{1}{2},\,\dot{x}(0)\,=\,0\,$.<br>
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 100;
#             padding: 10px 5px 10px 5px;
#             border: 10px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>This problem is set out in a straightforward way and needs no tricks.<br>
#
#  !| {x'' + 16 x = 2 sin(4 t)}, { x(0) = -1/2, x'(0) = 0}} |!<br>
#
# In Wolfram Alpha the expression is referred to as the "Differential equation solution":
#
#
# $x(t)\,=\,\normalsize \frac{1}{16}\,\small (\textrm{sin}\,(4t)\,-\,4\,(t\,+\,2)\,\textrm{cos}\,(4t))\,$
