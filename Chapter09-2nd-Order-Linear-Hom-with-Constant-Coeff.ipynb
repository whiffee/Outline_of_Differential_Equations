# %% [markdown]
# <div style="background: #DDE2FF;
#             font-family: Bookerly;
#             font-size: 14px;
#             font-weight: 500;
#             padding: 20px 5px 20px 5px;
#             border: 30px solid #DDE2FF;
#             margin-left: 1px;
#             margin-right: 1px;"
#
#  <font color='blue'>(Custom CSS files are not reliable for controlling Jupyter font style. To establish the same appearance as the original notebook, depend on the browser to control the font, by setting the desired font faces in the browser settings. For example, Chrome 135 or Firefox 134 can do this. In this notebook series, Bookerly font is for markdown and Monaco is for code.)
#
# <br>
# </div>

# %% [markdown]
# <div style="background: #DDE2FF;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 20px 5px 20px 5px;
#             border: 30px solid #DDE2FF;
#             margin-left: 1px;
#             margin-right: 1px;"
#
#  <font color='blue'>**Chapter 9: 2nd Order Linear Homogeneous ODEs with Constant Coefficients** <BR>
# <br>
#     Discussing a procedure for solving these 2nd order equations using a "characteristic equation" built specifically for the problem at hand. Wolfram Alpha does not need to refer to these characteristic equations and therefore that aspect of the solving process is completely lost in this version of the solutions.
#   </font>
#
#
#
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>**Cutting and pasting and Wolfram Alpha.** Wolfram Alpha is amenable to accepting pasted entries. In this chapter pastable expressions are given a distinctive boundary fence, exemplified by the sample:  !| abcdef |!<br>
# $\hspace{2 em}$In the above pseudo-entry, only the alpha characters would be copied for transfer to Wolfram Alpha.
#
#
#
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 50px 5px 50px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>9.1 Solve $\,y\,''\,-\,y\,'\,-\,2y\,=\,0\,$
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y'' - y' -2 * y = 0 |!<br><br>
# and the answer is received:<br><br>
# $$\,y\,=\,c_1\,e^{-x}\,+\,c_2\,e^{2x}\,$$<br><br>
# In this case the solution was arrived at without generating, factoring, or finding roots of the characteristic equation. Which probably defeats the purpose of the question.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 50px 5px 50px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>9.2 Solve $\,y\,''\,-\,7y\,'\,=\,0\,$
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y'' - 7 * y' = 0 |!<br><br>
# and the answer is received:<br><br>
# $$\,y\,=\,c_1\,e^{7x}\,+\,c_2\,$$<br><br>
# Yet again the solution was arrived at without generating, factoring, or finding roots of the characteristic equation.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 35px 5px 35px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>9.3 Solve $\,y\,''\,-\,5y\,=\,0\,$
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y'' - 5 * y = 0 |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_1\,e^{\sqrt{5}x}\,+\,c_2\,e^{-\sqrt{5}x}$$<br><br>
# Yet again the solution was arrived at without generating, factoring, or finding roots of the characteristic equation.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 15px 5px 15px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>9.5 Solve $\,\ddot{y}\,+\,10\dot{y}\,+\,21y\,=\,0\,$
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha, meanwhile giving it a clue as to the independent variable:<br><br>
# !| y''  + 10 * dy/dt + 21 * y = 0 |!<br><br>
# and the answer is received:<br><br>
# $$\,y(t)\,=\,c_1\,e^{-7t}\,+\,c_2\,e^{-3t}$$<br><br>
# Yet again the solution was arrived at without generating, factoring, or finding roots of the characteristic equation.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 15px 5px 15px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>9.6 Solve $\,\ddot{x}\,-\,0.01x\,=\,0\,$
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha, meanwhile giving it a clue as to the independent variable:<br><br>
# !| d^2 x/dt^2 - 0.01 * x = 0 |!<br><br>
# and the answer is received:<br><br>
# $$\,x(t)\,=\,c_1\,e^{0.1t}\,+\,c_2\,e^{-0.1t}$$<br><br>
# Yet again the solution was arrived at without generating, factoring, or finding roots of the characteristic equation.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 15px 5px 15px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>9.7 Solve $\,y\,''\,+\,4y\,'\,+\,5y\,=\,0\,$
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha.<br><br>
# !| y'' + 4 * y' + 5 * y = 0 |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_1\,e^{-2x}\textrm{sin}\,x\,+\,c_2\,e^{-2x}\textrm{cos}\,x\,$$<br><br>
# Yet again the solution was arrived at without generating, factoring, or finding roots of the characteristic equation.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 15px 5px 15px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>9.8 Solve $\,y\,''\,+\,4y\,=\,0\,$
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha.<br><br>
# !| y'' + 4 * y = 0 |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_2\,\textrm{sin}\,2x\,+\,c_1\,\textrm{cos}\,2x\,$$<br><br>
# Yet again the solution was arrived at without generating, factoring, or finding roots of the characteristic equation.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 15px 5px 15px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>9.9 Solve $\,y\,''\,+\,4y\,=\,0\,$
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha.<br><br>
# !| y''  - 3 * y ' + 4 * y = 0 |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_1\,e^{3x/2}\textrm{sin}\left(\frac{\sqrt{7}x}{2}\right)\,+\,c_2\,e^{3x/2}\,\textrm{cos}\left(\frac{\sqrt{7}x}{2}\right)\,$$<br><br>
# Yet again the solution was arrived at without generating, factoring, or finding roots of the characteristic equation.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 35px 5px 35px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>9.10  Solve $\,\ddot{y}\,-\,6\dot{y}\,+\,25y\,=\,0\,$
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha, including the clue about independent variable.<br><br>
# !| y'' - 6 * dy/dt + 25 * y = 0 |!<br><br>
# and the answer is received:<br><br>
# $$\,y(t)\,=\,c_1\,e^{3t}\textrm{sin}\,(4t)\,+\,c_2\,e^{3t}\,\textrm{cos}\,(4t)\,$$<br><br>
# Yet again the solution was arrived at without generating, factoring, or finding roots of the characteristic equation.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 35px 5px 35px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>9.11  Solve $\,\large \frac{d^2I}{dt^2}\small\,+\,20\,\large\frac{dI}{dt}\,\small+\,200I\,=\,0\,,$
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha, (including the necessary temporary substitution for the troublesome character 'I').<br><br>
# !| d^2C/dt^2 + 20 * dC/dt + 200 * C = 0 |!<br><br>
# and the answer is received:<br><br>
# $$\,I(t)\,=\,c_1\,e^{-10t}\textrm{sin}\,(10t)\,+\,c_2\,e^{-10t}\,\textrm{cos}\,(10t)\,$$<br><br>
# Yet again the solution was arrived at without generating, factoring, or finding roots of the characteristic equation.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 15px 5px 15px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>9.12  Solve $\,y\,''\,-\,8y\,'\,+\,16y\,=\,0t\,$
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y'' - 8 * y' + 16 * y = 0 |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_1\,e^{4x}\,+\,c_2\,e^{4x}\,x\,$$<br><br>
# Yet again the solution was arrived at without generating, factoring, or finding roots of the characteristic equation.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 15px 5px 15px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>9.13  Solve $\,y\,''\,=\,0\,$
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| y''  = 0 |!<br><br>
# and the answer is received:<br><br>
# $$\,y(x)\,=\,c_1\,+\,c_2x\,$$<br><br>
# Yet again the solution was arrived at without generating, factoring, or finding roots of the characteristic equation.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 15px 5px 15px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>9.14  Solve $\,\ddot{x}\,+\,4\dot{x}\,+\,4x\,=\,0\,$
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha, (including the hint about the identity of the independent variable):<br><br>
# !| x'' + 4 * dx/dt + 4 * x = 0 |!<br><br>
# and the answer is received:<br><br>
# $$\,x(t)\,=\,c_1e^{-2t}\,+\,c_2e^{-2t}t\,$$<br><br>
# Yet again the solution was arrived at without generating, factoring, or finding roots of the characteristic equation.
#
#
# </font>
# </div>

# %% [markdown]
# <div style="background: #FFE3CC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 15px 5px 15px 5px;
#             border: 30px solid #FFE3CC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>9.15  Solve $\,100\,\large\frac{d^2N}{dt^2}\,\small-\,20\,\large\frac{dN}{dt}\small\,+N\,=\,0\,$
# </font>
# </div>

# %% [markdown]
# <div style="background: #E2FFCC;
#             font-family: Bookerly;
#             font-size: 16px;
#             font-weight: 500;
#             padding: 10px 5px 10px 5px;
#             border: 30px solid #E2FFCC;
#             margin-left: 1px;
#             margin-right: 1px;"
#
# <font color='blue'>The entry is made into Wolfram Alpha:<br><br>
# !| 100 * d^2N/dt^2 - 20 * dN/dt + N = 0 |!<br><br>
# and the answer is received:<br><br>
# $$\,N(t)\,=\,c_1e^{t/10}\,+\,c_2e^{t/10}t\,$$<br><br>
# Yet again the solution was arrived at without generating, factoring, or finding roots of the characteristic equation.
#
#
# </font>
# </div>
